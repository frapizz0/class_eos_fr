# %%
# %pylab inline
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
#import uncertainties as un
pylab.rcParams['figure.figsize'] = (8, 6)
from scipy.interpolate import InterpolatedUnivariateSpline
#from classy import Class
#cosmo=Class()
#cosmo.empty()
#Listparams = dict()
pylab.rcParams['figure.figsize'] = (12, 8)
pylab.rc('text', usetex = True)
pylab.rc('font',**{'family':'sans-serif','sans-serif':['Helvetica']})

def print_now(msg):
    print msg
    sys.stdout.flush()
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from classy import Class
cosmo=Class()
cosmo.empty()



ListParams = {}


ListParams['MG/DE type']= 'fR'
ListParams['w_ds']= '-1.'
ListParams['cs2_ds']= '1.'
ListParams['B0']= '-3.'
ListParams['has_logB0']= '1.'
ListParams['a_start_ds']= '0.01'
#ListParams['P_k_max_h/Mpc']= '3.'


ListParams['gauge']= 'syn'


#l_max_scalars =  1
#k_max_tau0_over_l_max = .1

#ListParams['l_max_scalars']= '9000'
#ListParams['k_max_tau0_over_l_max']= '.1'






ListParams['Omega_fld']= '0.'
#ListParams['Omega0_ds']= '0.'

ListParams['Omega_Lambda']= '0.'
ListParams['Omega_scf']= '0.'
ListParams['Omega_ncdm']= '0.'
ListParams['Omega_k']= '0.'







ListParams['omega_cdm']= '0.1186'
ListParams['A_s']= '2.139e-9'
ListParams['omega_b']= '0.02226' 
#ListParams['100*theta_s']= '1.04085' 
ListParams['h']= '0.6781' 
ListParams['n_s']= '0.9677' 
ListParams['tau_reio']= '0.066'

ListParams['sBBN file'] = '/Users/apple/Desktop/Pheno_EOS/Codes/class_eos-v1.1/bbn/sBBN.dat' 
ListParams['k_pivot'] = 0.05

ListParams['N_ur'] = 2.0328 
ListParams['N_ncdm'] = 1 
ListParams['m_ncdm'] = 0.06 
ListParams['T_ncdm'] = 0.71611


ListParams['lensing']= 'no'

ListParams['P_k_max_h/Mpc']= '3.' 
ListParams['z_max_pk']= '10.1' 
ListParams['k_per_decade_for_pk']= '5'

ListParams['perturb_sampling_stepsize']= '0.01'
ListParams['tol_perturb_integration']= '1.e-9'

ListParams['non linear'] = ' '
#ListParams['k_output_values'] = '1.,.1,0.01,0.001,0.0001,0.00001'

#ListParams['temperature contributions'] = 'lisw'#, eisw, lisw, dop, pol'
ListParams['output'] = 'mPk,tCl' 
ListParams['perturbations_verbose'] = '10'
ListParams['background_verbose'] = '0'

ListParams['lensing_verbose'] = '10'


ListParams['spectra_verbose'] = '10'

# %%
PARAM = 'lensing'
VALUES = ['no']#, 'eisw', 'tsw', 'dop']



#k_in_inv_Mpc = np.logspace(-4,0,1000)
#PK = numpy.zeros(shape=(len(VALUES),len(k_in_inv_Mpc)))

#cl = numpy.zeros(shape=(len(VALUES),10000))
#cl_pp = numpy.zeros(shape=(len(VALUES),10000))

#ell = numpy.zeros(shape=(len(VALUES),10000))


#mu_z_0 = numpy.zeros(shape=(len(VALUES),len(k_in_inv_Mpc)))
#mu_z_5 = numpy.zeros(shape=(len(VALUES),len(k_in_inv_Mpc)))

#eta_z_0 = numpy.zeros(shape=(len(VALUES),len(k_in_inv_Mpc)))
#eta_z_5 = numpy.zeros(shape=(len(VALUES),len(k_in_inv_Mpc)))



for i in range (len(VALUES)):
    ListParams[PARAM] = VALUES[i]
    #if ListParams['lensing'] == 'yes':
    #    ListParams['output'] = 'tCl,lCl'
    #else:
    #    ListParams['output'] = 'tCl'
    cosmo.set(ListParams)
    cosmo.compute()
    print_now(PARAM)
    print VALUES[i]
    print 'sigma_8'
    print cosmo.sigma8()
    print 'cosmo.Omega0_m()'
    print cosmo.Omega0_m()
    #k_pivot = 0.05
    #for j in range (len(k_in_inv_Mpc)):
        #PK[i][j] =cosmo.pk(k_in_inv_Mpc[j], 0.)
        #mu_z_0[i][j] = cosmo.tk(k_in_inv_Mpc[j], 0.)[13]
        #eta_z_0[i][j] = cosmo.tk(k_in_inv_Mpc[j], 0.)[14]


        #mu_z_5[i][j] = cosmo.tk(k_in_inv_Mpc[j], 5.)[13]
        #eta_z_5[i][j] = cosmo.tk(k_in_inv_Mpc[j], 5.)[14]
    #for j in range (len(cosmo.raw_cl()['tt'])):
        #cl[i][j]=cosmo.raw_cl()['tt'][j]
    #cl[i] = cosmo.raw_cl()['tt']
        #if ListParams['lensing'] == 'yes':
            #cl_pp[i][j] = cosmo.raw_cl()['pp'][j]
            #cl[i][j]=cosmo.lensed_cl()['tt'][j]
        #ell[i][j] = cosmo.raw_cl()['ell'][j]
    #ELL_lensed = cosmo.lensed_cl()['ell'][j]

    #CL_lensed = cosmo.lensed_cl()['tt'][j]

    #CL_pp = cosmo.lensed_cl()['pp'][j]




    #cosmo.empty()
# Out:
# lensing
# no
# sigma_8
# 0.936643141946
# cosmo.Omega0_m()
# 0.307738509435

# %%
fig, (ax) = plt.subplots(1,1,figsize=(7,5))

label_size = 15
handle_length = 1.
labels = [r'$k=10^{-5}$',
          r'$k=10^{-4}$',
          r'$k=10^{-3}$',
          r'$k=10^{-2}$',
          r'$k=10^{-1}$',
          r'$k=10^{0}$',

          r'$\mathrm{\Lambda CDM}$',
           r'$w=-1.2$',
          r'$w=-1.05$',
          r'$w=-1.0$',
          r'$w=-0.9$',
          r'$w=-0.8$',
                  
         ]

#w=VALUES[0]
#g_lcdm = 6./11.
#g_wcdm = 3.*(1.-w)/(5.-6.*w)

#t = [0.6,0.45,0.30,0.15,0.]
t=0.
for i in range (2,5):
    print i
    gamma =  cosmo.get_perturbations()['scalar'][i]['gamma_m']
    a =  cosmo.get_perturbations()['scalar'][i]['a']
    z = 1/a-1
    t+=0.15
    col = (t, t, t)
    #ax.plot(z,gamma,label=labels[i],color=col)
    ode = 1.-cosmo.get_perturbations()['scalar'][i]['Omega_m']
    om = 1.-ode
    Delta_m = cosmo.get_perturbations()['scalar'][i]['Omega_m*Delta_m']/om
    om0 = om[len(om)-1]
    Delta_m0 = Delta_m[len(Delta_m)-1]
    Delta_m_prime = Delta_m*om**gamma/Delta_m0
    fsigma8=Delta_m_prime*cosmo.sigma8()
    K2 = cosmo.get_perturbations()['scalar'][i]['K2_ds']
    eps = 1.
    w=-1.
    g_st = 3.*(1.-eps)/(2.+3.*eps)/ode+3.*(eps-w)/(2.+3.*eps-6.*w)
    ax.plot(z,abs(fsigma8),label=labels[i],color=col)

ax.plot(zsigma8lcdm,abs(fsigma8lcdm),label=r'$\Lambda\mathrm{CDM}$',color='k',ls='--')

ax.fill_between(zsigma8lcdm, abs(fsigma8lcdm)*(1.-0.028), abs(fsigma8lcdm)*(1.+0.028),
                facecolor=(0.8,0.8,0.8))




zwiggleZ1 = 0.44
zwiggleZ2 = 0.6
zwiggleZ3 = 0.73
fsigma8WiggleZ1 = 0.436#0.413
fsigma8WiggleZ2 = 0.451#0.390
fsigma8WiggleZ3 = 0.48#0.437
zwiggleZ = [zwiggleZ1,zwiggleZ2,zwiggleZ3]
fsigma8WiggleZ = [fsigma8WiggleZ1,fsigma8WiggleZ2,fsigma8WiggleZ3]
errfsigma8wiggleZ = [0.058,0.0455,0.04]
z6d = 0.067
fsigma86d = 0.423
errfsigma86d = 0.055
zSDSS = 0.3
fsigma8sdss = 0.49
errfsigma8SDSS = np.sqrt(0.08**2.+0.04**2)
ax.errorbar(zwiggleZ,fsigma8WiggleZ,yerr=errfsigma8wiggleZ,capthick=1,capsize=3,elinewidth=1,\
             fmt='^',mfc='black',markersize=8,color = 'k',label = r'$\mathrm{WiggleZ}$')

ax.errorbar(zSDSS,fsigma8sdss,yerr=errfsigma8SDSS,capthick=1,capsize=3,elinewidth=1,\
             fmt='o',mfc='black',markersize=8,color = 'k',label = r'$\mathrm{SDSS}$')



ax.errorbar(z6d,fsigma86d,yerr=errfsigma86d,capthick=1,capsize=3,elinewidth=1,\
             fmt='v',mfc='black',markersize=8,color = 'k',label = r'$\mathrm{6dFGRS}$')






    #if i == 3:
#ax.plot(z,g_st,label=r'$\gamma_{_{\Lambda\mathrm{CDM}}}$',ls='--',c='k')

#ax.plot(z,g_lcdm*gamma/gamma,ls='--',c='k')
#ax.plot(z,g_wcdm*gamma/gamma,ls='--',c='r')


ax.set_xlim(0.01,0.82)
ax.set_ylim(0.35,.71)
ax.set_xscale('linear')
ax.legend()
ax.set_xlabel('$z$',size=20)
ax.set_ylabel('$f\sigma_8$',size=20)
ax.legend(loc=2,ncol=3,prop={'size':16},handlelength=handle_length,frameon=False)
ax.tick_params(axis = 'x',which='both',direction='in',length=5, pad=10)
ax.tick_params(axis = 'y',which='both',direction='in',length=5, pad=5)


plt.text(0.75,0.05,r'$B_{_0} = 0.01$\quad\quad\quad$w_{_\mathrm{de}} = -1$',horizontalalignment='center',
     verticalalignment='center', transform = ax.transAxes,fontsize=16)

#plt.text(0.5,0.05,r'$w_{_\mathrm{de}} = -0.8$\quad\quad\quad$c_{_{s,\mathrm{de}}}^2=1$',horizontalalignment='center',
#    verticalalignment='center', transform = ax.transAxes,fontsize=16)




ax.xaxis.set_ticks_position('both')

ax.yaxis.set_ticks_position('both')




plt.setp(ax.get_yticklabels(), rotation='vertical', fontsize=label_size)
plt.setp(ax.get_xticklabels(), fontsize=label_size)



fig.tight_layout()

plt.savefig("fsigma8.pdf")
# Out:
# 2
# 3
# 4
# /usr/local/lib/python2.7/site-packages/ipykernel/__main__.py:45: RuntimeWarning: invalid value encountered in divide

# %%
fsigma8
# Out:
# array([ -1.51694605e-06,   7.31231993e-08,   1.64404795e-07, ...,
#          8.05110269e-01,   8.06972069e-01,   8.07368309e-01])

# %%
fsigma8lcdm = np.zeros(len(fsigma8))
zsigma8lcdm = np.zeros(len(fsigma8))


for i in range (len(fsigma8)):
    fsigma8lcdm[i]=fsigma8[i]
    zsigma8lcdm[i]=z[i]

# %%
PARAM = 'B0'
VALUES = [-4]
#VALUES = ['HALOFIT']


k_in_inv_Mpc = np.logspace(-4,1.6,1000)
#PK = numpy.zeros(shape=(len(VALUES),len(k_in_inv_Mpc)))

sigma2 = numpy.zeros(shape=(len(VALUES),len(k_in_inv_Mpc)))


#PK_one_half = numpy.zeros(shape=(len(VALUES),len(k_in_inv_Mpc)))

#PK_one = numpy.zeros(shape=(len(VALUES),len(k_in_inv_Mpc)))

#PK_five = numpy.zeros(shape=(len(VALUES),len(k_in_inv_Mpc)))

#PK_ten = numpy.zeros(shape=(len(VALUES),len(k_in_inv_Mpc)))




#cl = numpy.zeros(shape=(len(VALUES),201))
#cl_pp = numpy.zeros(shape=(len(VALUES),201))

#ell = numpy.zeros(shape=(len(VALUES),201))


#mu_z_0 = numpy.zeros(shape=(len(VALUES),len(k_in_inv_Mpc)))
#mu_z_5 = numpy.zeros(shape=(len(VALUES),len(k_in_inv_Mpc)))

#eta_z_0 = numpy.zeros(shape=(len(VALUES),len(k_in_inv_Mpc)))
#eta_z_5 = numpy.zeros(shape=(len(VALUES),len(k_in_inv_Mpc)))



for i in range (len(VALUES)):
    ListParams[PARAM] = VALUES[i]
    cosmo.set(ListParams)
    cosmo.compute()
    print_now(PARAM)
    print VALUES[i]
    print 'sigma_8'
    print cosmo.sigma8()
    print 'cosmo.Omega0_m()'
    print cosmo.Omega0_m()
    k_pivot = 0.05
    #P_s = []
    #P_m = []
    #D_s = []
    #D_m = []
    #Om_m = []
    #pk_nl = []
    #z = 0.
    #for p in range (len(k_in_inv_Mpc)):
    #    Om_m.append(cosmo.tk(k_in_inv_Mpc[p], z)[17])
    #    pk_nl.append(cosmo.pk(k_in_inv_Mpc[p], z))
    #    P_s.append(cosmo.tk(k_in_inv_Mpc[p], z)[9])
    ##    P_m.append(cosmo.tk(k_in_inv_Mpc[p], z)[15])
    #   D_s.append(cosmo.tk(k_in_inv_Mpc[p], z)[12])
    #    D_m.append(cosmo.tk(k_in_inv_Mpc[p], z)[11])

    #P_m=np.asarray(P_m)
    #Om_m=np.asarray(Om_m)
    #pk_nl=np.asarray(pk_nl)
    #D_m=np.asarray(D_m)
    #P_s=np.asarray(P_s)
    #D_s=np.asarray(D_s)
    #primordial_pk = cosmo.A_s()*(k_in_inv_Mpc/cosmo.k_pivot())**(cosmo.n_s()-1.)
    #D_m_nl = -Om_m*np.sqrt(pk_nl)/np.sqrt(2.*np.pi**2*primordial_pk/k_in_inv_Mpc**3)
    #S2 = (1.+D_s/D_m_nl-P_s/D_m_nl-P_m/D_m_nl)**2

    #for j in range (len(k_in_inv_Mpc)): 
        #PK[i][j] =cosmo.pk(k_in_inv_Mpc[j], 0.)

     #   sigma2[i][j] =S2[j]


        #PK_one_half[i][j] =cosmo.pk(k_in_inv_Mpc[j], 0.5)

        #PK_one[i][j] =cosmo.pk(k_in_inv_Mpc[j], 1.)

        #PK_five[i][j] =cosmo.pk(k_in_inv_Mpc[j], 5.)

        #PK_ten[i][j] =cosmo.pk(k_in_inv_Mpc[j], 7.)



        #mu_z_0[i][j] = cosmo.tk(k_in_inv_Mpc[j], 0.)[13]
        #eta_z_0[i][j] = cosmo.tk(k_in_inv_Mpc[j], 0.)[14]


        #mu_z_5[i][j] = cosmo.tk(k_in_inv_Mpc[j], 5.)[13]
        #eta_z_5[i][j] = cosmo.tk(k_in_inv_Mpc[j], 5.)[14]
    #cl[i] = cosmo.raw_cl()['tt']

    #cl_pp[i] = cosmo.raw_cl()['pp']

    #ell[i] = cosmo.raw_cl()['ell']


    cosmo.empty()
# Out:
# ---------------------------------------------------------------------------
# CosmoSevereError                          Traceback (most recent call last)
# <ipython-input-4-ba2b49fd7976> in <module>()
#      38     ListParams[PARAM] = VALUES[i]
#      39     cosmo.set(ListParams)
# ---> 40     cosmo.compute()
#      41     print_now(PARAM)
#      42     print VALUES[i]
#
# classy.pyx in classy.Class.compute (classy.c:5150)()
#
# CosmoSevereError:
#
# Error in Class: input_init(L:495) :error in input_read_parameters(pfc, ppr, pba, pth, ppt, ptr, ppm, psp, pnl, ple, ptsz, pop, errmsg);
# =>input_read_parameters(L:1063) :condition ((flag1 == _TRUE_) && (flag2 == _TRUE_) && ((flag3 == _FALSE_) || (param3 >= 0.))) is true; In input file, either Omega_Lambda or Omega_fld must be left unspecified, except if Omega_scf is set and <0.0, in which case the contribution from the scalar field will be the free parameter.

# %%
fsigma8
# Out:
# array([            nan,             nan,             nan, ...,
#        -14952.23037354, -14948.95217608, -14942.97122169])

# %%
fig, (ax1) = plt.subplots(1,1,figsize=(7,5))



t = [0.]
label_size = 22
title_size = 25
legend_size = 22
handle_length = 1.
labels = [
    
        #r'$B_{_\mathrm{0}} =10^{-3}$',
          #r'$B_{_\mathrm{0}} =10^{-2}$',
          #r'$B_{_\mathrm{0}} =10^{-1}$',
          #r'$B_{_\mathrm{0}} =1$',

          #r'$B_{_\mathrm{0}} =5$',

          #r'$B_{_\mathrm{0}} =10$',
          r'$w_{_\mathrm{de}} =-1.4$',
          r'$w_{_\mathrm{de}} =-1.2$',
          r'$w_{_\mathrm{de}} =-1$',
          r'$w_{_\mathrm{de}} =-0.8$',
           r'$w_{_\mathrm{de}} =-0.6$',
          r'$\mathrm{\Lambda CDM}$',
           r'$w=-1.2$',
          r'$w=-1.05$',
          r'$w=-1.0$',
          r'$w=-0.9$',
          r'$w=-0.8$',
                  
         ]


for q in range (len(VALUES)):
    i = q
    if q>0:
        t.append(t[q-1]+0.15)
    #w = VALUES[i]
    #ode = 1.-0.314667075977
    #gamma_lcdm = 6./11.
    #gamma_wcdm = 3.*(1.-w)/(5.-6.*w)
    col = (t[q], t[q], t[q])
    #f = (1.+2./3./w*(gamma_wcdm+w*gamma_lcdm)*ode)
    #plt.plot(k_in_inv_Mpc/cosmo.h(),f**2*PK[i]/PK[i],ls = '--' )
    #plt.plot(k_in_inv_Mpc/cosmo.h(),PK[i]*cosmo.h()**3/PK[2]/cosmo.h()**3,label = VALUES[i])
    ax = ax1
    ax.plot(k_in_inv_Mpc/cosmo.h(),sigma2[i],
            label = labels[i],c=col)
    #ax = ax2
    #ax.plot(k_in_inv_Mpc/cosmo.h(),PK[i]/PKlcdm,label =labels[i],c=col)
    #ax.plot(k_in_inv_Mpc/cosmo.h(),PKlcdm/PKlcdm,ls = ':',c='k' )


#ax=ax1
#colo = 0.
#col = (colo, colo, colo)
#mu = []
#eta = []
#P_s = []
#P_m = []
#D_s = []
#D_m = []
#Om_m = []
#pk_nl = []
#z = 1.


#for i in range (len(k_in_inv_Mpc)):
##    eta.append(cosmo.tk(k_in_inv_Mpc[i], z)[14])
 #   Om_m.append(cosmo.tk(k_in_inv_Mpc[i], z)[17])
 #   mu.append(cosmo.tk(k_in_inv_Mpc[i], z)[13])
  #  pk_nl.append(cosmo.pk(k_in_inv_Mpc[i], 0.))
  #  P_s.append(cosmo.tk(k_in_inv_Mpc[i], z)[9])
  #  P_m.append(cosmo.tk(k_in_inv_Mpc[i], z)[15])
   # D_s.append(cosmo.tk(k_in_inv_Mpc[i], z)[12])
   # D_m.append(cosmo.tk(k_in_inv_Mpc[i], z)[11])

#P_m=np.asarray(P_m)
#Om_m=np.asarray(Om_m)
#pk_nl=np.asarray(pk_nl)
##D_m=np.asarray(D_m)
#P_s=np.asarray(P_s)
#D_s=np.asarray(D_s)
#primordial_pk = cosmo.A_s()*(k_in_inv_Mpc/cosmo.k_pivot())**(cosmo.n_s()-1.)
#D_m_nl = -Om_m*np.sqrt(pk_nl)/np.sqrt(2.*np.pi**2*primordial_pk/k_in_inv_Mpc**3)

    
#ax.plot(k_in_inv_Mpc/cosmo.h(),eta,c=col,label = r'$\eta$',ls='-')
#ax.plot(k_in_inv_Mpc/cosmo.h(),mu,c=col,label = r'$\mu$',ls='--')
#ax.plot(k_in_inv_Mpc/cosmo.h(),(1.+D_s/D_m)**-1.,c='r',label = r'$\mu_{nl}$',ls='--')
#ax.plot(k_in_inv_Mpc/cosmo.h(),(1.-2.*(P_m+P_s)/(D_m_nl+D_s))**-1.,c='r',label = r'$\eta_{nl}$',ls='-')

#ax.plot(k_in_inv_Mpc/cosmo.h(),cosmo.h()**3*pk_nl*(1.+D_s/D_m_nl-P_s/D_m_nl-P_m/D_m_nl)**2,c='k',
#        label = r'$z=0$',ls='-')
#ax.plot(k_in_inv_Mpc/cosmo.h(),cosmo.h()**3*pk_nl,c='k',
#        label = r'$z=$',ls='--')

#ax.plot(k_in_inv_Mpc/cosmo.h(),cosmo.h()**3*pk_nl*(1.+D_s/D_m_nl-P_s/D_m_nl-P_m/D_m_nl)**2,c='k',
#        label = r'$z=0$',ls='-')



#ax.plot(k_in_inv_Mpc/cosmo.h(),(1.+D_s/D_m_nl-P_s/D_m_nl-P_m/D_m_nl)**2,c='k',ls='--')


ax.plot(k_in_inv_Mpc/cosmo.h(),D_s/D_s,c='k',ls=':')






ax = ax1
ax.set_xlim(1.5e-4,50)
#ax.set_ylim(0.7,5.e1)
-
#plt.savefig("sigma2_w.pdf")



#plt.legend()

# %%
fig, (ax1) = plt.subplots(1,1,figsize=(7,5))



t = [0.]
label_size = 22
title_size = 25
legend_size = 22
handle_length = 1.
labels = [
    
        #r'$B_{_\mathrm{0}} =10^{-3}$',
          r'$B_{_\mathrm{0}} =10^{-2}$',
          r'$B_{_\mathrm{0}} =10^{-1}$',
          r'$B_{_\mathrm{0}} =1$',

          r'$B_{_\mathrm{0}} =5$',

          r'$B_{_\mathrm{0}} =10$',
          r'$w_{_\mathrm{de}} =-1.1$',
          r'$w_{_\mathrm{de}} =-1$',
          r'$w_{_\mathrm{de}} =-0.9$',
          r'$w_{_\mathrm{de}} =-0.8$',
           #r'$w_{_\mathrm{de}} =-0.6$',
          r'$\mathrm{\Lambda CDM}$',
           r'$w=-1.2$',
          r'$w=-1.05$',
          r'$w=-1.0$',
          r'$w=-0.9$',
          r'$w=-0.8$',
                  
         ]


for q in range (len(VALUES)-1):
    i = 4-q
    if q>0:
        t.append(t[q-1]+0.15)
    #w = VALUES[i]
    #ode = 1.-0.314667075977
    #gamma_lcdm = 6./11.
    #gamma_wcdm = 3.*(1.-w)/(5.-6.*w)
    col = (t[q], t[q], t[q])
    #f = (1.+2./3./w*(gamma_wcdm+w*gamma_lcdm)*ode)
    #plt.plot(k_in_inv_Mpc/cosmo.h(),f**2*PK[i]/PK[i],ls = '--' )
    #plt.plot(k_in_inv_Mpc/cosmo.h(),PK[i]*cosmo.h()**3/PK[2]/cosmo.h()**3,label = VALUES[i])
    ax = ax1
    ax.plot(k_in_inv_Mpc/cosmo.h(),sigma2[i],
            label = labels[i],c=col)
    #ax = ax2
    #ax.plot(k_in_inv_Mpc/cosmo.h(),PK[i]/PKlcdm,label =labels[i],c=col)
    #ax.plot(k_in_inv_Mpc/cosmo.h(),PKlcdm/PKlcdm,ls = ':',c='k' )


#ax=ax1
#colo = 0.
#col = (colo, colo, colo)
#mu = []
#eta = []
#P_s = []
#P_m = []
#D_s = []
#D_m = []
#Om_m = []
#pk_nl = []
#z = 1.


#for i in range (len(k_in_inv_Mpc)):
##    eta.append(cosmo.tk(k_in_inv_Mpc[i], z)[14])
 #   Om_m.append(cosmo.tk(k_in_inv_Mpc[i], z)[17])
 #   mu.append(cosmo.tk(k_in_inv_Mpc[i], z)[13])
  #  pk_nl.append(cosmo.pk(k_in_inv_Mpc[i], 0.))
  #  P_s.append(cosmo.tk(k_in_inv_Mpc[i], z)[9])
  #  P_m.append(cosmo.tk(k_in_inv_Mpc[i], z)[15])
   # D_s.append(cosmo.tk(k_in_inv_Mpc[i], z)[12])
   # D_m.append(cosmo.tk(k_in_inv_Mpc[i], z)[11])

#P_m=np.asarray(P_m)
#Om_m=np.asarray(Om_m)
#pk_nl=np.asarray(pk_nl)
##D_m=np.asarray(D_m)
#P_s=np.asarray(P_s)
#D_s=np.asarray(D_s)
#primordial_pk = cosmo.A_s()*(k_in_inv_Mpc/cosmo.k_pivot())**(cosmo.n_s()-1.)
#D_m_nl = -Om_m*np.sqrt(pk_nl)/np.sqrt(2.*np.pi**2*primordial_pk/k_in_inv_Mpc**3)

    
#ax.plot(k_in_inv_Mpc/cosmo.h(),eta,c=col,label = r'$\eta$',ls='-')
#ax.plot(k_in_inv_Mpc/cosmo.h(),mu,c=col,label = r'$\mu$',ls='--')
#ax.plot(k_in_inv_Mpc/cosmo.h(),(1.+D_s/D_m)**-1.,c='r',label = r'$\mu_{nl}$',ls='--')
#ax.plot(k_in_inv_Mpc/cosmo.h(),(1.-2.*(P_m+P_s)/(D_m_nl+D_s))**-1.,c='r',label = r'$\eta_{nl}$',ls='-')

#ax.plot(k_in_inv_Mpc/cosmo.h(),cosmo.h()**3*pk_nl*(1.+D_s/D_m_nl-P_s/D_m_nl-P_m/D_m_nl)**2,c='k',
#        label = r'$z=0$',ls='-')
#ax.plot(k_in_inv_Mpc/cosmo.h(),cosmo.h()**3*pk_nl,c='k',
#        label = r'$z=$',ls='--')

#ax.plot(k_in_inv_Mpc/cosmo.h(),cosmo.h()**3*pk_nl*(1.+D_s/D_m_nl-P_s/D_m_nl-P_m/D_m_nl)**2,c='k',
#        label = r'$z=0$',ls='-')



#ax.plot(k_in_inv_Mpc/cosmo.h(),(1.+D_s/D_m_nl-P_s/D_m_nl-P_m/D_m_nl)**2,c='k',ls='--')


ax.plot(k_in_inv_Mpc/cosmo.h(),D_s/D_s,c='k',ls=':')






ax = ax1
ax.set_xlim(1.5e-4,50)
ax.set_ylim(0.7,5.e1)
ax.set_xscale('log')
ax.set_yscale('log')

ax.set_xlabel('$k\,\,\,\,\,[h/\mathrm{Mpc}]$',size=title_size)
ax.set_ylabel('$\Sigma^2=[(1+\eta)/(2\mu\eta)]^2$',size=title_size)
ax.yaxis.set_label_coords(-.09,0.5) 


ax.legend(loc=1,ncol=2,prop={'size':legend_size},handlelength=handle_length,frameon=False)
ax.tick_params(axis = 'x',which='both',length=5,direction='in', pad=10)
ax.tick_params(axis = 'y',which='both',length=5,direction='in', pad=5)


#plt.text(0.6,0.93,r'$B_{_0} = 1$\quad\quad\quad$w_{_\mathrm{de}} = -0.8$',horizontalalignment='center',
#     verticalalignment='center', transform = ax.transAxes,fontsize=16)

#plt.text(0.9,0.9,r'$c_{_{s,\mathrm{de}}}^2=1$',horizontalalignment='center',
#     verticalalignment='center', transform = ax.transAxes,fontsize=legend_size)

plt.text(0.85,0.5,r'$w_{_\mathrm{de}}=-1$',horizontalalignment='center',
     verticalalignment='center', transform = ax.transAxes,fontsize=legend_size)



plt.setp(ax.get_yticklabels(), rotation='vertical', fontsize=label_size)
plt.setp(ax.get_xticklabels(), fontsize=label_size)




fig.tight_layout()
plt.savefig("sigma2_B.pdf")



#plt.legend()

# %%
fig, (ax1) = plt.subplots(1,1,figsize=(7,5))



t = [0.]
label_size = 22
title_size = 25
legend_size = 22
handle_length = 1.
labels = [
    
        #r'$B_{_\mathrm{0}} =10^{-3}$',
          #r'$B_{_\mathrm{0}} =10^{-2}$',
          #r'$B_{_\mathrm{0}} =10^{-1}$',
          #r'$B_{_\mathrm{0}} =1$',
          #r'$B_{_\mathrm{0}} =10$',
          r'$w_{_\mathrm{de}} =-1.1$',
          r'$w_{_\mathrm{de}} =-1$',
          r'$w_{_\mathrm{de}} =-0.9$',
          r'$w_{_\mathrm{de}} =-0.8$',
           #r'$w_{_\mathrm{de}} =-0.6$',
          r'$\mathrm{\Lambda CDM}$',
           r'$w=-1.2$',
          r'$w=-1.05$',
          r'$w=-1.0$',
          r'$w=-0.9$',
          r'$w=-0.8$',
                  
         ]


#for i in range (len(VALUES)):
    #if i>0:
        #t.append(t[i-1]+0.15)
    #w = VALUES[i]
    #ode = 1.-0.314667075977
    #gamma_lcdm = 6./11.
    #gamma_wcdm = 3.*(1.-w)/(5.-6.*w)
    #col = (t[i], t[i], t[i])
    #f = (1.+2./3./w*(gamma_wcdm+w*gamma_lcdm)*ode)
    #plt.plot(k_in_inv_Mpc/cosmo.h(),f**2*PK[i]/PK[i],ls = '--' )
    #plt.plot(k_in_inv_Mpc/cosmo.h(),PK[i]*cosmo.h()**3/PK[2]/cosmo.h()**3,label = VALUES[i])
    #ax = ax1
    #ax.plot(k_in_inv_Mpc/cosmo.h(),PK[i]*cosmo.h()**3,
    #        label = labels[i],c=col)
    #ax = ax2
    #ax.plot(k_in_inv_Mpc/cosmo.h(),PK[i]/PKlcdm,label =labels[i],c=col)
    #ax.plot(k_in_inv_Mpc/cosmo.h(),PKlcdm/PKlcdm,ls = ':',c='k' )


ax=ax1
colo = 0.
col = (colo, colo, colo)
ax.plot(k_in_inv_Mpc/cosmo.h(),np.sqrt(PK[1]/PK[0]),c=col,label = r'$z=0$',ls='-')
colo += 0.15
col = (colo, colo, colo)

ax.plot(k_in_inv_Mpc/cosmo.h(),np.sqrt(PK_one_half[1]/PK_one_half[0]),label = r'$z=0.5$',c=col,ls='-')
colo += 0.15
col = (colo, colo, colo)



ax.plot(k_in_inv_Mpc/cosmo.h(),np.sqrt(PK_one[1]/PK_one[0]),c=col,
        label = r'$z=1$',ls='-')
colo += 0.15
col = (colo, colo, colo)



ax.plot(k_in_inv_Mpc/cosmo.h(),np.sqrt(PK_five[1]/PK_five[0]),label = r'$z=5$',c=col,ls='-')
colo += 0.15
col = (colo, colo, colo)



ax.plot(k_in_inv_Mpc/cosmo.h(),np.sqrt(PK_ten[1]/PK_ten[0]),label = r'$z=7$',c=col,ls='-')





ax = ax1
ax.set_xlim(1.5e-2,50)
#ax.set_ylim(0.7,4.)
ax.set_xscale('log')
ax.set_yscale('log')

ax.set_xlabel('$k\,\,\,\,\,[h/\mathrm{Mpc}]$',size=title_size)
ax.set_ylabel('$\Delta_{_{\mathrm{m}}}^{^\mathrm{NL}}/\Delta_{_{\mathrm{m}}}$',size=title_size)
ax.yaxis.set_label_coords(-.05,0.5) 


ax.legend(loc=2,ncol=1,prop={'size':legend_size},handlelength=handle_length,frameon=False)
ax.tick_params(axis = 'x',which='both',length=5,direction='in', pad=10)
ax.tick_params(axis = 'y',which='both',length=5,direction='in', pad=5)


#plt.text(0.6,0.93,r'$B_{_0} = 1$\quad\quad\quad$w_{_\mathrm{de}} = -0.8$',horizontalalignment='center',
#     verticalalignment='center', transform = ax.transAxes,fontsize=16)

#plt.text(0.9,0.9,r'$c_{_{s,\mathrm{de}}}^2=1$',horizontalalignment='center',
#     verticalalignment='center', transform = ax.transAxes,fontsize=legend_size)

#plt.text(0.7,0.9,r'$B_{_\mathrm{0}}=1$',horizontalalignment='center',
#     verticalalignment='center', transform = ax.transAxes,fontsize=legend_size)



plt.setp(ax.get_yticklabels(), rotation='vertical', fontsize=label_size)
plt.setp(ax.get_xticklabels(), fontsize=label_size)




fig.tight_layout()
plt.savefig("pk_hf_z.pdf")



#plt.legend()

# %%
fig, (ax1,ax2) = plt.subplots(1,2,figsize=(13,5))



t = [0.]
label_size = 22
title_size = 25
legend_size = 22
handle_length = 1.
labels = [
    
        #r'$B_{_\mathrm{0}} =10^{-3}$',
          #r'$B_{_\mathrm{0}} =10^{-2}$',
          #r'$B_{_\mathrm{0}} =10^{-1}$',
          #r'$B_{_\mathrm{0}} =1$',
          #r'$B_{_\mathrm{0}} =10$',
          r'$w_{_\mathrm{de}} =-1.1$',
          r'$w_{_\mathrm{de}} =-1$',
          r'$w_{_\mathrm{de}} =-0.9$',
          r'$w_{_\mathrm{de}} =-0.8$',
           #r'$w_{_\mathrm{de}} =-0.6$',
          r'$\mathrm{\Lambda CDM}$',
           r'$w=-1.2$',
          r'$w=-1.05$',
          r'$w=-1.0$',
          r'$w=-0.9$',
          r'$w=-0.8$',
                  
         ]


#for i in range (len(VALUES)):
    #if i>0:
        #t.append(t[i-1]+0.15)
    #w = VALUES[i]
    #ode = 1.-0.314667075977
    #gamma_lcdm = 6./11.
    #gamma_wcdm = 3.*(1.-w)/(5.-6.*w)
    #col = (t[i], t[i], t[i])
    #f = (1.+2./3./w*(gamma_wcdm+w*gamma_lcdm)*ode)
    #plt.plot(k_in_inv_Mpc/cosmo.h(),f**2*PK[i]/PK[i],ls = '--' )
    #plt.plot(k_in_inv_Mpc/cosmo.h(),PK[i]*cosmo.h()**3/PK[2]/cosmo.h()**3,label = VALUES[i])
    #ax = ax1
    #ax.plot(k_in_inv_Mpc/cosmo.h(),PK[i]*cosmo.h()**3,
    #        label = labels[i],c=col)
    #ax = ax2
    #ax.plot(k_in_inv_Mpc/cosmo.h(),PK[i]/PKlcdm,label =labels[i],c=col)
    #ax.plot(k_in_inv_Mpc/cosmo.h(),PKlcdm/PKlcdm,ls = ':',c='k' )
ax = ax1

ax.plot(k_in_inv_Mpc/cosmo.h(),PK[1]*cosmo.h()**3,
            label = r'$\mathrm{halofit}$',c='k',ls='-')

ax.plot(k_in_inv_Mpc/cosmo.h(),PK[0]*cosmo.h()**3,
            label = r'$\mathrm{linear}$',c='k',ls='--')


ax=ax2
ax.plot(k_in_inv_Mpc/cosmo.h(),np.sqrt(PK[1]/PK[0]),c='k',ls='-')


ax = ax1
ax.set_xlim(1.5e-4,50)
ax.set_ylim(0.2,5.e4)
ax.set_xscale('log')
ax.set_yscale('log')

ax.set_xlabel('$k\,\,\,\,\,[h/\mathrm{Mpc}]$',size=title_size)
ax.set_ylabel('$P(k)\,\,\,\,[\mathrm{Mpc}/h]^3$',size=title_size)
ax.yaxis.set_label_coords(-.09,0.5) 
ax.legend(loc=3,ncol=1,prop={'size':legend_size},handlelength=handle_length,frameon=False)
ax.tick_params(axis = 'x',which='both',length=5,direction='in', pad=10)
ax.tick_params(axis = 'y',which='both',length=5,direction='in', pad=5)


#plt.text(0.6,0.93,r'$B_{_0} = 1$\quad\quad\quad$w_{_\mathrm{de}} = -0.8$',horizontalalignment='center',
#     verticalalignment='center', transform = ax.transAxes,fontsize=16)

#plt.text(0.5,0.05,r'$w_{_\mathrm{de}} = -0.8$\quad\quad\quad$c_{_{s,\mathrm{de}}}^2=1$',horizontalalignment='center',
#     verticalalignment='center', transform = ax.transAxes,fontsize=16)

#plt.text(0.9,0.9,r'$c_{_{s,\mathrm{de}}}^2=1$',horizontalalignment='center',
#     verticalalignment='center', transform = ax.transAxes,fontsize=legend_size)
#plt.text(0.9,0.9,r'$B_{_\mathrm{0}}=1$',horizontalalignment='center',
#     verticalalignment='center', transform = ax.transAxes,fontsize=legend_size)




plt.setp(ax.get_yticklabels(), rotation='vertical', fontsize=label_size)
plt.setp(ax.get_xticklabels(), fontsize=label_size)



ax = ax2
ax.set_xlim(1.5e-4,50)
#ax.set_ylim(0.7,4.)
ax.set_xscale('log')
ax.set_yscale('log')

ax.set_xlabel('$k\,\,\,\,\,[h/\mathrm{Mpc}]$',size=title_size)
ax.set_ylabel('$\Delta_{_{\mathrm{m}}}^{^\mathrm{NL}}/\Delta_{_{\mathrm{m}}}$',size=title_size)
ax.yaxis.set_label_coords(-.03,0.5) 


ax.legend(loc=2,ncol=1,prop={'size':legend_size},handlelength=handle_length,frameon=False)
ax.tick_params(axis = 'x',which='both',length=5,direction='in', pad=10)
ax.tick_params(axis = 'y',which='both',length=5,direction='in', pad=5)


#plt.text(0.6,0.93,r'$B_{_0} = 1$\quad\quad\quad$w_{_\mathrm{de}} = -0.8$',horizontalalignment='center',
#     verticalalignment='center', transform = ax.transAxes,fontsize=16)

#plt.text(0.9,0.9,r'$c_{_{s,\mathrm{de}}}^2=1$',horizontalalignment='center',
#     verticalalignment='center', transform = ax.transAxes,fontsize=legend_size)

#plt.text(0.7,0.9,r'$B_{_\mathrm{0}}=1$',horizontalalignment='center',
#     verticalalignment='center', transform = ax.transAxes,fontsize=legend_size)



plt.setp(ax.get_yticklabels(), rotation='vertical', fontsize=label_size)
plt.setp(ax.get_xticklabels(), fontsize=label_size)




fig.tight_layout(pad=2.)
#plt.savefig("pk_lin_hf.pdf")



#plt.legend()

# %%
cl_lensed_lcdm = np.zeros(len(cosmo.lensed_cl()['tt']))

ell_lensed_lcdm = np.zeros(len(cosmo.lensed_cl()['tt']))

#cl_pp_lcdm = np.zeros(3001)

for i in range (len(cosmo.lensed_cl()['tt'])):
    cl_lensed_lcdm[i] = cosmo.lensed_cl()['tt'][i]

    ell_lensed_lcdm[i] = cosmo.lensed_cl()['ell'][i]

    #cl_pp_lcdm[i] = cl_pp[0][i]

# %%
cl_unlensed_lcdm = np.zeros(len(cosmo.raw_cl()['tt']))

ell_unlensed_lcdm = np.zeros(len(cosmo.raw_cl()['tt']))

#cl_pp_lcdm = np.zeros(3001)

for i in range (len(cosmo.lensed_cl()['tt'])):
    cl_unlensed_lcdm[i] = cosmo.raw_cl()['tt'][i]

    ell_unlensed_lcdm[i] = cosmo.raw_cl()['ell'][i]

    #cl_pp_l

# %%
fig, (ax1,ax2) = plt.subplots(1,2,figsize=(13,5))



#t = [0.45,0.30,0.15,0.]

t = [0.]

label_size = 22
title_size = 25
legend_size = 20
handle_length = 1.
labels = [
    
              #r'$\mathrm{LISW}$',

              #r'$\mathrm{EISW}$',

              #r'$\mathrm{tSW}$',

              #r'$\mathrm{Doppler}$',

              #r'$\mathrm{POL}$',
          #r'$\mathrm{\Lambda CDM}$',




        r'$B_{_\mathrm{0}} =10^{-2}$',
        r'$B_{_\mathrm{0}} =10^{-1}$',
        r'$B_{_\mathrm{0}} =1$',
        r'$B_{_\mathrm{0}} =5$',
        r'$B_{_\mathrm{0}} =10$',
          r'$w_{_\mathrm{de}} =-1$',
          r'$w_{_\mathrm{de}} =-0.9$',
          r'$w_{_\mathrm{de}} =-0.8$',
          r'$w_{_\mathrm{de}} =-0.7$',
           #r'$w_{_\mathrm{de}} =-0.6$',
          r'$\mathrm{\Lambda CDM}$',
           r'$w=-1.2$',
          r'$w=-1.05$',
          r'$w=-1.0$',
          r'$w=-0.9$',
          r'$w=-0.8$',
                  
         ]


#for i in range (len(VALUES)):
    #if i>0:
    #    t.append(t[i-1]+0.15)
    #w = VALUES[i]
    #ode = 1.-0.314667075977
    #gamma_lcdm = 6./11.
    #gamma_wcdm = 3.*(1.-w)/(5.-6.*w)
    #col = (t[i], t[i], t[i])
    #f = (1.+2./3./w*(gamma_wcdm+w*gamma_lcdm)*ode)
    #plt.plot(k_in_inv_Mpc/cosmo.h(),f**2*PK[i]/PK[i],ls = '--' )
    #plt.plot(k_in_inv_Mpc/cosmo.h(),PK[i]*cosmo.h()**3/PK[2]/cosmo.h()**3,label = VALUES[i])
ax = ax1
ELL = ell_lensed_lcdm
CL = cl_lensed_lcdm
ax.plot(ELL,ELL*(ELL+1.)*CL/2./np.pi,
            label = r'$\mathrm{lensed}$',c='k')


ELL = ell_unlensed_lcdm
CL = cl_unlensed_lcdm
ax.plot(ELL,ELL*(ELL+1.)*CL/2./np.pi,
            label = r'$\mathrm{unlensed}$',c='k',ls='--')


    #ax.plot(k_in_inv_Mpc/cosmo.h(),PKlcdm/PKlcdm,ls = ':',c='k' )
#ax = ax1
#ax.plot(ELL,ELL*(ELL+1.)*cl_lisw_lcdm[:len(ELL)]/2./np.pi,
#            label = r'$\Lambda\mathrm{CDM}$',c='k',ls=':')

ax = ax2
#ELL = ell[i][1:9000]
#CL = cl[1][1:3000]
#CL_pp = cl_pp[0][1:9000]

ax.plot(ELL,(cl_lensed_lcdm-cl_unlensed_lcdm)/cl_lensed_lcdm,c='k')


ax.plot(ELL,0.*(cl_lensed_lcdm-cl_unlensed_lcdm)/cl_lensed_lcdm,c='k',ls=':')







ax = ax1
ax.set_xlim(2,9000)
#ax.set_ylim(2.e-14,5.e-8)
ax.set_xscale('log')
ax.set_yscale('log')

ax.set_xlabel('$\ell$',size=title_size)
ax.set_ylabel('$\ell(\ell+1)C_\ell/ 2\pi$',size=title_size)
ax.yaxis.set_label_coords(-.07,0.5) 
ax.legend(loc=3,ncol=1,prop={'size':legend_size},handlelength=handle_length,frameon=False)
ax.tick_params(axis = 'x',which='both',length=5,direction='in', pad=10)
ax.tick_params(axis = 'y',which='both',length=5,direction='in', pad=5)


#plt.text(0.6,0.93,r'$B_{_0} = 1$\quad\quad\quad$w_{_\mathrm{de}} = -0.8$',horizontalalignment='center',
#     verticalalignment='center', transform = ax.transAxes,fontsize=16)

#plt.text(0.2,0.1,r'$w_{_\mathrm{de}} = -1$',horizontalalignment='center',
#     verticalalignment='center', transform = ax.transAxes,fontsize=legend_size)

#plt.text(0.9,0.9,r'$c_{_{s,\mathrm{de}}}^2=1$',horizontalalignment='center',
#     verticalalignment='center', transform = ax.transAxes,fontsize=legend_size)
#plt.text(0.9,0.9,r'$B_{_\mathrm{0}}=1$',horizontalalignment='center',
#     verticalalignment='center', transform = ax.transAxes,fontsize=legend_size)




plt.setp(ax.get_yticklabels(), rotation='vertical', fontsize=18)
plt.setp(ax.get_xticklabels(), fontsize=label_size)

ax = ax2
ax.set_xlim(2,3000)
ax.set_ylim(-0.07,0.17)
#ax.set_xscale('log')
#ax.set_yscale('log')

ax.set_xlabel('$\ell$',size=title_size)
ax.set_ylabel('$\Delta C_\ell/C_\ell$',size=title_size)
ax.yaxis.set_label_coords(-.07,0.5) 
#ax.legend(loc=1,ncol=2,prop={'size':legend_size},handlelength=handle_length,frameon=False)
ax.tick_params(axis = 'x',which='both',length=5,direction='in', pad=10)
ax.tick_params(axis = 'y',which='both',length=5,direction='in', pad=5)


#plt.text(0.6,0.93,r'$B_{_0} = 1$\quad\quad\quad$w_{_\mathrm{de}} = -0.8$',horizontalalignment='center',
#     verticalalignment='center', transform = ax.transAxes,fontsize=16)

#plt.text(0.2,0.1,r'$w_{_\mathrm{de}} = -1$',horizontalalignment='center',
#     verticalalignment='center', transform = ax.transAxes,fontsize=legend_size)

#plt.text(0.9,0.9,r'$c_{_{s,\mathrm{de}}}^2=1$',horizontalalignment='center',
#     verticalalignment='center', transform = ax.transAxes,fontsize=legend_size)
#plt.text(0.9,0.9,r'$B_{_\mathrm{0}}=1$',horizontalalignment='center',
#     verticalalignment='center', transform = ax.transAxes,fontsize=legend_size)




plt.setp(ax.get_yticklabels(), rotation='vertical', fontsize=label_size)
plt.setp(ax.get_xticklabels(), fontsize=label_size)








fig.tight_layout(pad=1.9)
plt.savefig("cl_lensed_unlensed.pdf")



#plt.legend()
# Out:
# /usr/local/lib/python2.7/site-packages/ipykernel/__main__.py:83: RuntimeWarning: invalid value encountered in divide
# /usr/local/lib/python2.7/site-packages/ipykernel/__main__.py:86: RuntimeWarning: invalid value encountered in divide

# %%
fig, (ax1) = plt.subplots(1,1,figsize=(7,5))



#t = [0.45,0.30,0.15,0.]

t = [0.]

label_size = 22
title_size = 25
legend_size = 20
handle_length = 1.
labels = [
    
        #r'$B_{_\mathrm{0}} =10^{-2}$',
        #r'$B_{_\mathrm{0}} =10^{-1}$',
        #r'$B_{_\mathrm{0}} =1$',
        #r'$B_{_\mathrm{0}} =5$',
        #r'$B_{_\mathrm{0}} =10$',
          r'$w_{_\mathrm{de}} =-1$',
          r'$w_{_\mathrm{de}} =-0.9$',
          r'$w_{_\mathrm{de}} =-0.8$',
          r'$w_{_\mathrm{de}} =-0.7$',
           #r'$w_{_\mathrm{de}} =-0.6$',
          r'$\mathrm{\Lambda CDM}$',
           r'$w=-1.2$',
          r'$w=-1.05$',
          r'$w=-1.0$',
          r'$w=-0.9$',
          r'$w=-0.8$',
                  
         ]


for i in range (len(VALUES)):
    if i>0:
        t.append(t[i-1]+0.15)
    w = VALUES[i]
    ode = 1.-0.314667075977
    #gamma_lcdm = 6./11.
    #gamma_wcdm = 3.*(1.-w)/(5.-6.*w)
    col = (t[i], t[i], t[i])
    #f = (1.+2./3./w*(gamma_wcdm+w*gamma_lcdm)*ode)
    #plt.plot(k_in_inv_Mpc/cosmo.h(),f**2*PK[i]/PK[i],ls = '--' )
    #plt.plot(k_in_inv_Mpc/cosmo.h(),PK[i]*cosmo.h()**3/PK[2]/cosmo.h()**3,label = VALUES[i])
    ax = ax1
    ELL = ell[i]
    CL = cl_pp[i]
    ax.plot(ELL,(ELL*(ELL+1.))**2*CL/2./np.pi,
            label = labels[i],c=col)
    #ax = ax2
    #ax.plot(k_in_inv_Mpc/cosmo.h(),PK[i]/PKlcdm,label =labels[i],c=col)
    #ax.plot(k_in_inv_Mpc/cosmo.h(),PKlcdm/PKlcdm,ls = ':',c='k' )
ax = ax1
#ax.plot(k_in_inv_Mpc/cosmo.h(),PKlcdm*cosmo.h()**3,
#            label = r'$\Lambda\mathrm{CDM}$',c='k',ls=':')

ax.plot(ELL,(ELL*(ELL+1.))**2*cl_pp_lcdm/2./np.pi,
            label = r'$\Lambda\mathrm{CDM}$',c='k',ls=':')




ax = ax1
ax.set_xlim(2,2000)
#ax.set_ylim(0.45,.70)
ax.set_xscale('log')
ax.set_yscale('log')

ax.set_xlabel('$\ell$',size=title_size)
ax.set_ylabel('$[\ell(\ell+1)]^2 C_\ell^{\phi \phi} / 2\pi$',size=title_size)
ax.yaxis.set_label_coords(-.07,0.5) 
ax.legend(loc=3,ncol=2,prop={'size':legend_size},handlelength=handle_length,frameon=False)
ax.tick_params(axis = 'x',which='both',length=5,direction='in', pad=10)
ax.tick_params(axis = 'y',which='both',length=5,direction='in', pad=5)


#plt.text(0.6,0.93,r'$B_{_0} = 1$\quad\quad\quad$w_{_\mathrm{de}} = -0.8$',horizontalalignment='center',
#     verticalalignment='center', transform = ax.transAxes,fontsize=16)

#plt.text(0.5,0.05,r'$w_{_\mathrm{de}} = -0.8$\quad\quad\quad$c_{_{s,\mathrm{de}}}^2=1$',horizontalalignment='center',
#     verticalalignment='center', transform = ax.transAxes,fontsize=16)

#plt.text(0.9,0.9,r'$c_{_{s,\mathrm{de}}}^2=1$',horizontalalignment='center',
#     verticalalignment='center', transform = ax.transAxes,fontsize=legend_size)
plt.text(0.9,0.9,r'$B_{_\mathrm{0}}=1$',horizontalalignment='center',
     verticalalignment='center', transform = ax.transAxes,fontsize=legend_size)




plt.setp(ax.get_yticklabels(), rotation='vertical', fontsize=label_size)
plt.setp(ax.get_xticklabels(), fontsize=label_size)






fig.tight_layout()
plt.savefig("cl_pp_fR_B0=1.pdf")



#plt.legend()

# %%
#fig, ((ax1,ax2),(ax3,ax4)) = plt.subplots(2,2,figsize=(15,10))

fig, (ax1) = plt.subplots(1,1,figsize=(7,5))




t = [0.60,0.45,0.30,0.15,0.]
label_size = 22
title_size = 25
legend_size = 20
handle_length = 1.
labels = [
    
        #r'$B_{_\mathrm{0}} =10^{-3}$',
          #r'$B_{_\mathrm{0}} =10^{-2}$',
          #r'$B_{_\mathrm{0}} =10^{-1}$',
          #r'$B_{_\mathrm{0}} =1$',
          #r'$B_{_\mathrm{0}} =10$',
          r'$w_{_\mathrm{de}} =-1.4$',
          r'$w_{_\mathrm{de}} =-1.2$',
          r'$w_{_\mathrm{de}} =-0.8$',
          r'$w_{_\mathrm{de}} =-0.6$',
           #r'$w_{_\mathrm{de}} =-0.6$',
          r'$\mathrm{\Lambda CDM}$',
           r'$w=-1.2$',
          r'$w=-1.05$',
          r'$w=-1.0$',
          r'$w=-0.9$',
          r'$w=-0.8$',
                  
         ]


for i in range (len(VALUES)):
    w = VALUES[i]
    ode = 1.-0.314667075977
    gamma_lcdm = 6./11.
    gamma_wcdm = 3.*(1.-w)/(5.-6.*w)
    col = (t[i], t[i], t[i])
    #f = (1.+2./3./w*(gamma_wcdm+w*gamma_lcdm)*ode)
    #plt.plot(k_in_inv_Mpc/cosmo.h(),f**2*PK[i]/PK[i],ls = '--' )
    #plt.plot(k_in_inv_Mpc/cosmo.h(),PK[i]*cosmo.h()**3/PK[2]/cosmo.h()**3,label = VALUES[i])
    ax = ax1
    ax.plot(k_in_inv_Mpc/cosmo.h(),mu_z_0[i],
            label = labels[i],c=col)
    '''
    ax = ax2
    ax.plot(k_in_inv_Mpc/cosmo.h(),mu_z_5[i]-1.,label =labels[i],c=col)

    ax = ax3
    ax.plot(k_in_inv_Mpc/cosmo.h(),eta_z_0[i]-1.,
            label = labels[i],c=col)
    ax = ax4
    ax.plot(k_in_inv_Mpc/cosmo.h(),eta_z_5[i]-1.,label =labels[i],c=col)
    '''
ax.plot(k_in_inv_Mpc/cosmo.h(),mu_z_0[i]/mu_z_0[i],
            ls =':' ,c='k')



ax = ax1
ax.set_xlim(1.5e-4,1)
#ax.set_ylim(-2.,3.)
ax.set_xscale('log')
ax.set_yscale('linear')

ax.set_xlabel('$k\,\,\,\,\,[h/\mathrm{Mpc}]$',size=title_size)
ax.set_ylabel(r'$\mu(k)\quad\mathrm{at}\quad z=0$',size=title_size)
ax.yaxis.set_label_coords(-.07,0.5) 
ax.legend(loc=4,ncol=2,prop={'size':legend_size},handlelength=handle_length,frameon=False)
ax.tick_params(axis = 'x',which='both',length=5,direction='in', pad=10)
ax.tick_params(axis = 'y',which='both',length=5,direction='in', pad=5)

plt.text(0.9,0.9,r'$c_{_{s,\mathrm{de}}}^2=1$',horizontalalignment='center',
     verticalalignment='center', transform = ax.transAxes,fontsize=legend_size)


#plt.text(0.9,0.9,r'$w_{_\mathrm{de}}=-1$',horizontalalignment='center',
#     verticalalignment='center', transform = ax.transAxes,fontsize=legend_size)

plt.setp(ax.get_yticklabels(), rotation='vertical', fontsize=label_size)
plt.setp(ax.get_xticklabels(), fontsize=label_size)


''''
ax = ax2
ax.set_xlim(1.5e-4,1)
#ax.set_ylim(0.7,4.)
ax.set_xscale('log')
ax.set_yscale('linear')

ax.set_xlabel('$k\,\,\,\,\,[h/\mathrm{Mpc}]$',size=title_size)
ax.set_ylabel('$\mu(k)\quad\mathrm{at}\quad z=5$',size=title_size)
ax.legend(loc='center left',ncol=1,prop={'size':legend_size},handlelength=handle_length,frameon=False)
ax.tick_params(axis = 'x',which='both',length=5,direction='in', pad=10)
ax.tick_params(axis = 'y',which='both',length=5,direction='in', pad=5)


#plt.text(0.6,0.93,r'$B_{_0} = 1$\quad\quad\quad$w_{_\mathrm{de}} = -0.8$',horizontalalignment='center',
#     verticalalignment='center', transform = ax.transAxes,fontsize=16)

plt.text(0.9,0.9,r'$c_{_{s,\mathrm{de}}}^2=1$',horizontalalignment='center',
     verticalalignment='center', transform = ax.transAxes,fontsize=legend_size)

#plt.text(0.1,0.9,r'$w_{_\mathrm{de}}=-1$',horizontalalignment='center',
#     verticalalignment='center', transform = ax.transAxes,fontsize=legend_size)



plt.setp(ax.get_yticklabels(), rotation='vertical', fontsize=label_size)
plt.setp(ax.get_xticklabels(), fontsize=label_size)

#####ax3-4

ax = ax3
ax.set_xlim(1.5e-4,1)
#ax.set_ylim(0.45,.70)
ax.set_xscale('log')
ax.set_yscale('linear')

ax.set_xlabel('$k\,\,\,\,\,[h/\mathrm{Mpc}]$',size=title_size)
ax.set_ylabel(r'$\eta(k)\quad\mathrm{at}\quad z=0$',size=title_size)
ax.yaxis.set_label_coords(-.07,0.5) 
ax.legend(loc=4,ncol=1,prop={'size':legend_size},handlelength=handle_length,frameon=False)
ax.tick_params(axis = 'x',which='both',length=5,direction='in', pad=10)
ax.tick_params(axis = 'y',which='both',length=5,direction='in', pad=5)


#plt.text(0.9,0.9,r'$w_{_\mathrm{de}}=1$',horizontalalignment='center',
#     verticalalignment='center', transform = ax.transAxes,fontsize=legend_size)

plt.text(0.9,0.9,r'$c_{_{s,\mathrm{de}}}^2=1$',horizontalalignment='center',
     verticalalignment='center', transform = ax.transAxes,fontsize=legend_size)




plt.setp(ax.get_yticklabels(), rotation='vertical', fontsize=label_size)
plt.setp(ax.get_xticklabels(), fontsize=label_size)



ax = ax4
ax.set_xlim(1.5e-4,1)
#ax.set_ylim(0.7,4.)
ax.set_xscale('log')
ax.set_yscale('linear')

ax.set_xlabel('$k\,\,\,\,\,[h/\mathrm{Mpc}]$',size=title_size)
ax.set_ylabel('$\eta(k)\quad\mathrm{at}\quad z=5$',size=title_size)
ax.legend(loc=3,ncol=1,prop={'size':legend_size},handlelength=handle_length,frameon=False)
ax.tick_params(axis = 'x',which='both',length=5,direction='in', pad=10)
ax.tick_params(axis = 'y',which='both',length=5,direction='in', pad=5)


#plt.text(0.6,0.93,r'$B_{_0} = 1$\quad\quad\quad$w_{_\mathrm{de}} = -0.8$',horizontalalignment='center',
#     verticalalignment='center', transform = ax.transAxes,fontsize=16)

plt.text(0.9,0.9,r'$c_{_{s,\mathrm{de}}}^2=1$',horizontalalignment='center',
     verticalalignment='center', transform = ax.transAxes,fontsize=legend_size)

#plt.text(0.9,0.9,r'$w_{_\mathrm{de}}=-1$',horizontalalignment='center',
#     verticalalignment='center', transform = ax.transAxes,fontsize=legend_size)



plt.setp(ax.get_yticklabels(), rotation='vertical', fontsize=label_size)
plt.setp(ax.get_xticklabels(), fontsize=label_size)

'''



fig.tight_layout()
plt.savefig("mu_eta_vs_k_qe_w_varying.pdf")



#plt.legend()

# %%
fig, (ax1,ax2) = plt.subplots(1,2,figsize=(15,5))



t = [0.60,0.45,0.30,0.15,0.]
label_size = 22
title_size = 25
legend_size = 20
handle_length = 1.
labels = [
    
        #r'$B_{_\mathrm{0}} =10^{-3}$',
          #r'$B_{_\mathrm{0}} =10^{-2}$',
          #r'$B_{_\mathrm{0}} =10^{-1}$',
          #r'$B_{_\mathrm{0}} =1$',
          #r'$B_{_\mathrm{0}} =10$',
          r'$w_{_\mathrm{de}} =-1.1$',
          r'$w_{_\mathrm{de}} =-1$',
          r'$w_{_\mathrm{de}} =-0.9$',
          r'$w_{_\mathrm{de}} =-0.8$',
           #r'$w_{_\mathrm{de}} =-0.6$',
          r'$\mathrm{\Lambda CDM}$',
           r'$w=-1.2$',
          r'$w=-1.05$',
          r'$w=-1.0$',
          r'$w=-0.9$',
          r'$w=-0.8$',
                  
         ]


for i in range (len(VALUES)):
    w = VALUES[i]
    ode = 1.-0.314667075977
    gamma_lcdm = 6./11.
    gamma_wcdm = 3.*(1.-w)/(5.-6.*w)
    col = (t[i], t[i], t[i])
    #f = (1.+2./3./w*(gamma_wcdm+w*gamma_lcdm)*ode)
    #plt.plot(k_in_inv_Mpc/cosmo.h(),f**2*PK[i]/PK[i],ls = '--' )
    #plt.plot(k_in_inv_Mpc/cosmo.h(),PK[i]*cosmo.h()**3/PK[2]/cosmo.h()**3,label = VALUES[i])
    ax = ax1
    ax.plot(k_in_inv_Mpc/cosmo.h(),PK[i]*cosmo.h()**3,
            label = labels[i],c=col)
    ax = ax2
    ax.plot(k_in_inv_Mpc/cosmo.h(),PK[i]/PKlcdm,label =labels[i],c=col)
    ax.plot(k_in_inv_Mpc/cosmo.h(),PKlcdm/PKlcdm,ls = ':',c='k' )
ax = ax1
ax.plot(k_in_inv_Mpc/cosmo.h(),PKlcdm*cosmo.h()**3,
            label = r'$\Lambda\mathrm{CDM}$',c='k',ls=':')

ax = ax1
ax.set_xlim(1.5e-4,1)
#ax.set_ylim(0.45,.70)
ax.set_xscale('log')
ax.set_yscale('log')

ax.set_xlabel('$k\,\,\,\,\,[h/\mathrm{Mpc}]$',size=title_size)
ax.set_ylabel('$P(k)\,\,\,\,[\mathrm{Mpc}/h]^3$',size=title_size)
ax.yaxis.set_label_coords(-.07,0.5) 
ax.legend(loc=3,ncol=2,prop={'size':legend_size},handlelength=handle_length,frameon=False)
ax.tick_params(axis = 'x',which='both',length=5,direction='in', pad=10)
ax.tick_params(axis = 'y',which='both',length=5,direction='in', pad=5)


#plt.text(0.6,0.93,r'$B_{_0} = 1$\quad\quad\quad$w_{_\mathrm{de}} = -0.8$',horizontalalignment='center',
#     verticalalignment='center', transform = ax.transAxes,fontsize=16)

#plt.text(0.5,0.05,r'$w_{_\mathrm{de}} = -0.8$\quad\quad\quad$c_{_{s,\mathrm{de}}}^2=1$',horizontalalignment='center',
#     verticalalignment='center', transform = ax.transAxes,fontsize=16)

#plt.text(0.9,0.9,r'$c_{_{s,\mathrm{de}}}^2=1$',horizontalalignment='center',
#     verticalalignment='center', transform = ax.transAxes,fontsize=legend_size)
plt.text(0.9,0.9,r'$B_{_\mathrm{0}}=1$',horizontalalignment='center',
     verticalalignment='center', transform = ax.transAxes,fontsize=legend_size)




plt.setp(ax.get_yticklabels(), rotation='vertical', fontsize=label_size)
plt.setp(ax.get_xticklabels(), fontsize=label_size)



ax = ax2
ax.set_xlim(1.5e-4,1)
ax.set_ylim(0.7,4.)
ax.set_xscale('log')
ax.set_yscale('linear')

ax.set_xlabel('$k\,\,\,\,\,[h/\mathrm{Mpc}]$',size=title_size)
ax.set_ylabel('$P(k)/P(k)^{^{\Lambda\mathrm{CDM}}}$',size=title_size)
ax.legend(loc=2,ncol=1,prop={'size':legend_size},handlelength=handle_length,frameon=False)
ax.tick_params(axis = 'x',which='both',length=5,direction='in', pad=10)
ax.tick_params(axis = 'y',which='both',length=5,direction='in', pad=5)


#plt.text(0.6,0.93,r'$B_{_0} = 1$\quad\quad\quad$w_{_\mathrm{de}} = -0.8$',horizontalalignment='center',
#     verticalalignment='center', transform = ax.transAxes,fontsize=16)

#plt.text(0.9,0.9,r'$c_{_{s,\mathrm{de}}}^2=1$',horizontalalignment='center',
#     verticalalignment='center', transform = ax.transAxes,fontsize=legend_size)

plt.text(0.7,0.9,r'$B_{_\mathrm{0}}=1$',horizontalalignment='center',
     verticalalignment='center', transform = ax.transAxes,fontsize=legend_size)



plt.setp(ax.get_yticklabels(), rotation='vertical', fontsize=label_size)
plt.setp(ax.get_xticklabels(), fontsize=label_size)




fig.tight_layout()
#plt.savefig("pk_fR_B0=1.pdf")



#plt.legend()

# %%
fig, (ax1) = plt.subplots(1,1,figsize=(7,5))

label_size = 15
handle_length = 1.
labels = [r'$k=10^{-5}$',
          r'$k=10^{-4}$',
          r'$k=10^{-3}$',
          r'$k=10^{-2}$',
          r'$k=10^{-1}$',
          r'$k=1$',


          r'$\mathrm{\Lambda CDM}$',
           r'$w=-1.2$',
          r'$w=-1.05$',
          r'$w=-1.0$',
          r'$w=-0.9$',
          r'$w=-0.8$',
                  
         ]

w=VALUES[0]
g_lcdm = 6./11.
g_wcdm = 3.*(1.-w)/(5.-6.*w)

t = [0.75,0.60,0.45,0.30,0.15,0.]

for i in range (6):
    Om_ds_D_ds =  cosmo.get_perturbations()['scalar'][i]['Omega_ds*Delta_ds']
    Om_m_D_m =  cosmo.get_perturbations()['scalar'][i]['Omega_m*Delta_m']
    Om_m = cosmo.get_perturbations()['scalar'][i]['Omega_m']
    Om_ds = 1.-Om_m
    K2 = cosmo.get_perturbations()['scalar'][i]['K2_ds']
    M2 = cosmo.get_perturbations()['scalar'][i]['M2_ds']
    epsilonH_bar = cosmo.get_perturbations()['scalar'][i]['epsilon_H_bar']
    epsilonH = cosmo.get_perturbations()['scalar'][i]['epsilon_H']

    fR = cosmo.get_perturbations()['scalar'][i]['fR_ds']
    fR_prime = cosmo.get_perturbations()['scalar'][i]['fR_prime_ds']



    attractor = -1./3.*K2*Om_m_D_m/(K2+M2)

    attractor2 = -epsilonH_bar/M2*(1.-2.*epsilonH_bar/epsilonH*fR/fR_prime)*Om_m_D_m



    a =  cosmo.get_perturbations()['scalar'][i]['a']
    z = 1/a-1
    col = (t[i], t[i], t[i])
    ax = ax1
    ax.plot(z,abs(Om_ds_D_ds),label=labels[i],color=col)
    if i>1:
        ax.plot(z,abs(attractor),color=col,ls='--')

    #ax.plot(z,abs(attractor2),color=col,ls=':')


    
ax = ax1
#ax.plot(z,1.5*mu/mu,ls='--',c='k')
#ax.plot(z,1.*a/a,ls=':',c='k')


ax.set_xlim(0.01,200.)
ax.set_ylim(2.e-7,1.e8)
ax.set_xscale('log')

ax.set_yscale('log')

ax.legend()
ax.set_xlabel('$z$',size=20)
ax.set_ylabel('$\Omega_{_\mathrm{de}} \Delta_{_\mathrm{de}}$',size=20)
ax.legend(loc='upper center',ncol=3,prop={'size':16},handlelength=handle_length,frameon=False)
ax.tick_params(axis = 'x',length = 5,which='both',direction='in', pad=10)
ax.tick_params(axis = 'y',length = 5,which='both',direction='in', pad=5)
#ax.yaxis.set_label_coords(-.1,0.5) 



plt.text(0.25,0.07,r'$B_{_0} = 1$\quad\quad\quad$w_{_\mathrm{de}} = -1$',horizontalalignment='center',
     verticalalignment='center', transform = ax.transAxes,fontsize=16)

#plt.text(0.2,0.1,r'$a_{_\mathrm{ini}} = 0.1$',horizontalalignment='center',
#     verticalalignment='center', transform = ax.transAxes,fontsize=16)

#plt.text(0.18,0.2,r'$B_{_{\mathrm{0}}}=1$',horizontalalignment='center',
#     verticalalignment='center', transform = ax.transAxes,fontsize=16)


plt.setp(ax.get_yticklabels(),  rotation='vertical', fontsize=label_size)
plt.setp(ax.get_xticklabels(), fontsize=label_size)





fig.tight_layout()

plt.savefig("Om_ds_D_ds_vs_z.pdf")

# %%
fig, (ax1,ax2) = plt.subplots(1,2,figsize=(10,5))

label_size = 15
handle_length = 1.
labels = [r'$k=10^{-4}$',
          r'$k=10^{-3}$',
          r'$k=10^{-2}$',
          r'$k=10^{-1}$',
          r'$\mathrm{\Lambda CDM}$',
           r'$w=-1.2$',
          r'$w=-1.05$',
          r'$w=-1.0$',
          r'$w=-0.9$',
          r'$w=-0.8$',
                  
         ]

w=VALUES[0]
g_lcdm = 6./11.
g_wcdm = 3.*(1.-w)/(5.-6.*w)

t = [0.45,0.30,0.15,0.]

for i in range (4):
    mu =  cosmo.get_perturbations()['scalar'][i]['mu']
    eta =  cosmo.get_perturbations()['scalar'][i]['eta']
    a =  cosmo.get_perturbations()['scalar'][i]['a']
    z = 1/a-1
    col = (t[i], t[i], t[i])
    ax = ax1
    ax.plot(z,mu,label=labels[i],color=col)
    ax = ax2
    ax.plot(z,eta,label=labels[i],color=col)
    
ax = ax1
#ax.plot(z,1.5*mu/mu,ls='--',c='k')
ax.plot(z,1.*mu/mu,ls=':',c='k')


ax.set_xlim(0.01,99.)
ax.set_ylim(0.981,1.11)
ax.set_xscale('log')

ax.set_yscale('linear')

ax.legend()
ax.set_xlabel('$z$',size=20)
ax.set_ylabel('$\mu(z,k)',size=20)
ax.legend(loc='center right',ncol=1,prop={'size':16},handlelength=handle_length,frameon=False)
ax.tick_params(axis = 'x',which='both',direction='in', pad=10)
ax.tick_params(axis = 'y',which='both',direction='in', pad=5)
ax.yaxis.set_label_coords(-.1,0.5) 



#plt.text(0.6,0.93,r'$B_{_0} = 1$\quad\quad\quad$w_{_\mathrm{de}} = -0.8$',horizontalalignment='center',
#     verticalalignment='center', transform = ax.transAxes,fontsize=16)

plt.text(0.5,0.93,r'$w_{_\mathrm{de}} = -1.4$\quad\quad\quad$c_{_{s,\mathrm{de}}}^2=1$',horizontalalignment='center',
     verticalalignment='center', transform = ax.transAxes,fontsize=16)

plt.setp(ax.get_yticklabels(), rotation='vertical', fontsize=label_size)
plt.setp(ax.get_xticklabels(), fontsize=label_size)



ax = ax2
#ax.plot(z,0.5*mu/mu,ls='--',c='k')
ax.plot(z,1.*mu/mu,ls=':',c='k')


ax.set_xlim(0.01,99.)
ax.set_ylim(0.975,1.03)
ax.set_xscale('log')
ax.legend()
ax.set_xlabel('$z$',size=20)
ax.set_ylabel(r'$\eta(z,k)',size=20)
ax.legend(loc='lower center',ncol=2,prop={'size':16},handlelength=handle_length,frameon=False)
ax.tick_params(axis = 'x',which='both',direction='in', pad=10)
ax.tick_params(axis = 'y',which='both',direction='in', pad=5)
ax.yaxis.set_label_coords(-.1,0.5) 



#plt.text(0.6,0.93,r'$B_{_0} = 1$\quad\quad\quad$w_{_\mathrm{de}} = -0.8$',horizontalalignment='center',
#     verticalalignment='center', transform = ax.transAxes,fontsize=16)

plt.text(0.5,0.93,r'$w_{_\mathrm{de}} = -1.4$\quad\quad\quad$c_{_{s,\mathrm{de}}}^2=1$',horizontalalignment='center',
     verticalalignment='center', transform = ax.transAxes,fontsize=16)

plt.setp(ax.get_yticklabels(), rotation='vertical', fontsize=label_size)
plt.setp(ax.get_xticklabels(), fontsize=label_size)






fig.tight_layout()

plt.savefig("mu_eta_qe_w=-1.4.pdf")

# %%
fig, (ax) = plt.subplots(1,1,figsize=(5,5))

label_size = 15
handle_length = 1.
labels = [r'$k=10^{-4}$',
          r'$k=10^{-3}$',
          r'$k=10^{-2}$',
          r'$k=10^{-1}$',
          r'$\mathrm{\Lambda CDM}$',
           r'$w=-1.2$',
          r'$w=-1.05$',
          r'$w=-1.0$',
          r'$w=-0.9$',
          r'$w=-0.8$',
                  
         ]

w=VALUES[0]
g_lcdm = 6./11.
g_wcdm = 3.*(1.-w)/(5.-6.*w)

t = [0.45,0.30,0.15,0.]

for i in range (4):
    gamma =  cosmo.get_perturbations()['scalar'][i]['gamma_m']
    a =  cosmo.get_perturbations()['scalar'][i]['a']
    z = 1/a-1
    col = (t[i], t[i], t[i])
    ax.plot(z,gamma,label=labels[i],color=col)
    ode = 1.-cosmo.get_perturbations()['scalar'][i]['Omega_m']
    K2 = cosmo.get_perturbations()['scalar'][i]['K2_ds']
    eps = 1.
    g_st = 3.*(1.-eps)/(2.+3.*eps)/ode+3.*(eps-w)/(2.+3.*eps-6.*w)
    if i == 3:
        ax.plot(z,g_st,label=r'$\gamma_{_{\Lambda\mathrm{CDM}}}$',ls='--',c='k')

#ax.plot(z,g_lcdm*gamma/gamma,ls='--',c='k')
#ax.plot(z,g_wcdm*gamma/gamma,ls='--',c='r')


ax.set_xlim(0.01,4)
ax.set_ylim(0.45,.70)
ax.set_xscale('linear')
ax.legend()
ax.set_xlabel('$z$',size=20)
ax.set_ylabel('$\gamma = \log(\Delta_{_\mathrm{m}}^\prime/\Delta_{_\mathrm{m}})/\log(\Omega_{_\mathrm{m}})$',size=20)
ax.legend(loc=2,ncol=2,prop={'size':16},handlelength=handle_length,frameon=False)
ax.tick_params(axis = 'x',which='both',direction='in', pad=10)
ax.tick_params(axis = 'y',which='both',direction='in', pad=5)


#plt.text(0.6,0.93,r'$B_{_0} = 1$\quad\quad\quad$w_{_\mathrm{de}} = -0.8$',horizontalalignment='center',
#     verticalalignment='center', transform = ax.transAxes,fontsize=16)

plt.text(0.5,0.05,r'$w_{_\mathrm{de}} = -0.8$\quad\quad\quad$c_{_{s,\mathrm{de}}}^2=1$',horizontalalignment='center',
     verticalalignment='center', transform = ax.transAxes,fontsize=16)





plt.setp(ax.get_yticklabels(), rotation='vertical', fontsize=label_size)
plt.setp(ax.get_xticklabels(), fontsize=label_size)



fig.tight_layout()

#plt.savefig("gamma_qe_w=-0.8.pdf")

# %%
cosmo.get_perturbations()['scalar'][i].keys()
# Out:
# ['shear_ncdm[0]',
#  'Omega_ds*Theta_ds',
#  'Omega_ds*wGamma_ds',
#  'Omega_ds*wPi_ds',
#  'fR_prime_ds',
#  'delta_ur',
#  'Omega_m*wGamma_m',
#  'epsilon_H',
#  'delta_cdm',
#  'theta_cdm',
#  'theta_ur',
#  'M2_ds',
#  'Z_ds',
#  'Omega_m*Theta_m',
#  'cs2_ncdm[0]',
#  'K2_ds',
#  'fR_ds',
#  'gamma_m',
#  'phi',
#  'psi',
#  'shear_ur',
#  'delta_ncdm[0]',
#  'epsilon_H_bar',
#  'alpha',
#  'delta_g',
#  'Omega_m*Delta_m',
#  'delta_b',
#  'a',
#  'theta_g',
#  'pol0_g',
#  'theta_b',
#  'shear_g',
#  'tau [Mpc]',
#  'Omega_m*wPi_m',
#  'Delta_m',
#  'pol2_g',
#  'Omega_m',
#  'B',
#  'Omega_ds*Delta_ds',
#  'pol1_g',
#  'theta_ncdm[0]']

# %%
PKlcdm = np.zeros(len(k_in_inv_Mpc))
for i in range (len(k_in_inv_Mpc)):
    PKlcdm[i] = PK[0][i]

# %%
plt.plot(k_in_inv_Mpc,PKlcdm)
plt.loglog()
# Out:
# []

# %%
plt.plot(k_in_inv_Mpc,PKlcdm)
plt.loglog()
# Out:
# []

# %%
from scipy import interpolate as itp


PATH_TO_CFHTLS ='/Users/apple/Downloads/montepython_public-2.2.2/data/'
# This function is used to convert 2D sums over the two indices (Bin1, Bin2) of an N*N symmetric matrix
# into 1D sums over one index with N(N+1)/2 possible values
def one_dim_index(Bin1,Bin2):
    if Bin1 <= Bin2:
        return Bin2+self.nbin*Bin1-(Bin1*(Bin1+1))/2
    else:
        return Bin1+self.nbin*Bin2-(Bin2*(Bin2+1))/2


# data and precision parameters for the CFHTLens correlation #
# function's likelihood (from Heymans et al. 1303.1808)      #
##############################################################
class CFHTLens_correlation:
    def __init__(self):
        self.data_directory = PATH_TO_CFHTLS

# number of tomographic redshift bins of the survey
        self.nbin = 6
# number of angular bins in which xipm is measured
        self.ntheta = 5

# Measurements (xi+,xi-) and covariance matrix
        self.xipm_file = "CFHTLENS/cfhtlens_xipm_6bin_blu.dat"
        self.covmat_file = "CFHTLENS/covariance_matrix_blu.dat"

# Selection function file
        self.window_file = ["CFHTLENS/nofz_%dblu.hist" % (i + 1) for i in range(self.nbin)]
# number of discrete z values in selection function file
        self.nzmax = 72
# maximum redshift covered by survey
        self.zmax = 3.52
# sky coverage
# self.fsky = 0.375 (not used)

# Use angular mask (to cut non-linear scales)
        self.use_cut_theta = True
# if True, select a cut scheme:
#self.cutvalues_file = "CFHTLENS/cut_values_none.dat"
        #self.cutvalues_file = "CFHTLENS/cut_values_conservative.dat"
        self.cutvalues_file = "CFHTLENS/cut_values_ultra_conservative.dat"

# maximum l for C_l
        self.lmax = 50000
# logarithmic l step for C_l
        self.dlnl = 0.4

# parameters controlling the precision of the integral
# for the correlation function (int l C_l J(x))
# through the stepsize of x == l * theta
# (this also controls the speed of the likelihood,
# since this integral is the bottleneck)
        self.xmax = 50.
        self.dx_below_threshold = 0.05
        self.dx_above_threshold = 0.15
        self.dx_threshold = 0.4


# precision with which bin edges are computed
# self.dz = 0.01 (not used)

# k_max in h/Mpc
# (should be increased when using less conservative cut scheme)
#self.k_max_h_by_Mpc = 50.0 #default
        self.k_max_h_by_Mpc = 1.0

# Anderson-Hartlap factor
        self.ah_factor = 0.873

# Uncomment this line to use the theoretical error nuisance parameter
# self.use_nuisance = ['epsilon']

# Nonlinear corrections
        self.use_halofit = True

        self.coefficient_f_nu = 0
        self.theoretical_error = 0
# noise computation
        self.rms_shear = 0.0
# number of galaxies per square arcminutes
        self.gal_per_sqarcmn = 30

# precision of the Bessel integration
# self.nz_wl = 95 (not used)
        self.dlntheta = 0.25
        self.dx = 0.02
        self.xstop = 200.0
        self.use_nuisance ={}
self = CFHTLens_correlation()

import os
import math
# Define array of l values, and initialize them
# It is a logspace
# find nlmax in order to reach lmax with logarithmic steps dlnl
self.nlmax = np.int(np.log(self.lmax)/self.dlnl)+1
# redefine slightly dlnl so that the last point is always exactly lmax
self.dlnl = np.log(self.lmax)/(self.nlmax-1)
self.l = np.exp(self.dlnl*np.arange(self.nlmax))
# Read dn_dz from window files
self.z_p = np.zeros(self.nzmax)
zptemp = np.zeros(self.nzmax)
self.p = np.zeros((self.nzmax, self.nbin))
for i in xrange(self.nbin):
    window_file_path = os.path.join(
                self.data_directory, self.window_file[i])
    if os.path.exists(window_file_path):
        zptemp = np.loadtxt(window_file_path, usecols=[0])
        if (i > 0 and np.sum((zptemp-self.z_p)**2) > 1e-6):
            print  "The redshift values for the window files at different bins do not match"
        self.z_p = zptemp
        self.p[:, i] = np.loadtxt(window_file_path, usecols=[1])
    else:
        print "File not found:\n %s" %window_file_path



#PLOT FOR PAPER

labels = [r'$k$',
          r'$k$',
          r'$k$',
          r'$k$',

          r'$k$',

          r'$\mathrm{\Lambda CDM}$',
         ]
colors = ['blue','orange','green','red','k','purple']




N_plots = self.nbin


label_size = 15
handle_length = 1.
fig, (ax1) = plt.subplots(1,1,figsize=(8,5))

ax = ax1
for i in range (N_plots):
    ax.plot(self.z_p,self.p[:,i],label=labels[i],color=colors[i])

    
ax.set_xlim(0.01,1.5)
ax.set_ylim(0.01,0.7)
ax.set_xscale('linear')   
ax.set_yscale('linear')
ax.set_xlabel('$z$',size=20)
ax.set_ylabel('$(dn/dz)$',size=20)
ax.legend(loc=1,prop={'size':16},ncol=2,handlelength=handle_length,frameon=False)
ax.tick_params(axis = 'x',which='both',direction='in', pad=10)
ax.tick_params(axis = 'y',which='both',direction='in', pad=5)


#plt.text(0.9,0.1,r'$B_{_0} = 1$',horizontalalignment='center',
#     verticalalignment='center', transform = ax.transAxes,fontsize=16)




plt.setp(ax.get_yticklabels(), rotation='vertical', fontsize=label_size)
plt.setp(ax.get_xticklabels(), fontsize=label_size)



fig.tight_layout()

#plt.savefig("dndzCFHT.pdf")




# Read measurements of xi+ and xi-
nt = (self.nbin)*(self.nbin+1)/2
self.theta_bins = np.zeros(2*self.ntheta)
self.xi_obs = np.zeros(self.ntheta*nt*2)
xipm_file_path = os.path.join(
            self.data_directory, self.xipm_file)

if os.path.exists(xipm_file_path):
    self.theta_bins = np.loadtxt(xipm_file_path)[:, 0]
    temp = np.loadtxt(xipm_file_path)[:, 1:]
else:
    raise "File not found:\n %s"%xipm_file_path


k = 0
for j in xrange(nt):
    for i in xrange(2*self.ntheta):
        self.xi_obs[k]=temp[i,j]
        k = k+1


# Read covariance matrix
ndim = (self.ntheta)*(self.nbin)*(self.nbin+1)
covmat = np.zeros((ndim, ndim))
covmat_file_path = os.path.join(self.data_directory, self.covmat_file)
if os.path.exists(covmat_file_path):
    covmat = np.loadtxt(covmat_file_path)
else:
    print ("File not found:\n %s"%covmat_file_path)

covmat = covmat/self.ah_factor

# Read angular cut values (OPTIONAL)
if (self.use_cut_theta):
    cut_values = np.zeros((self.nbin, 2))
    cutvalues_file_path = os.path.join(self.data_directory, self.cutvalues_file)
    if os.path.exists(cutvalues_file_path):
        cut_values = np.loadtxt(cutvalues_file_path)
    else:
        print ("File not found:\n %s"%cutvalues_file_path)

# Normalize selection functions
self.p_norm = np.zeros(self.nbin, 'float64')
for Bin in xrange(self.nbin):
    self.p_norm[Bin] = np.sum(0.5*(self.p[1:, Bin]+self.p[:-1, Bin])*(self.z_p[1:]-self.z_p[:-1]))
# Compute theta mask
if (self.use_cut_theta):
    mask = np.zeros(2*nt*self.ntheta)
    iz = 0
    for izl in xrange(self.nbin):
        for izh in xrange(izl, self.nbin):
# this counts the bin combinations
# iz=1 =>(1,1), iz=2 =>(1,2) etc
            iz = iz + 1
            for i in xrange(self.ntheta):
                j = (iz-1)*2*self.ntheta
                xi_plus_cut = max(cut_values[izl, 0], cut_values[izh, 0])
                xi_minus_cut = max(
                            cut_values[izl, 1], cut_values[izh, 1])
                if (self.theta_bins[i] > xi_plus_cut):
                    mask[j+i] = 1
                if (self.theta_bins[i] > xi_minus_cut):
                    mask[self.ntheta + j+i] = 1
else:
    mask = np.ones(2*nt*self.ntheta)
self.num_mask = int(np.sum(mask))
self.mask_indices = np.zeros(int(self.num_mask))

j = 0
for i in xrange(self.ntheta*nt*2):
            
        if (mask[i] == 1):
            self.mask_indices[j] = i
            j = j+1
self.mask_indices = np.int32(self.mask_indices)
# Precompute masked inverse
self.wl_invcov = np.zeros((self.num_mask, self.num_mask))
self.wl_invcov = covmat[self.mask_indices][:, self.mask_indices]
self.wl_invcov = np.linalg.inv(self.wl_invcov)

# Fill array of discrete z values
# self.z = np.linspace(0, self.zmax, num=self.nzmax)

################
# Noise spectrum
################

# Number of galaxies per steradian
self.noise = 3600.*self.gal_per_sqarcmn*(180./math.pi)**2

# Number of galaxies per steradian per bin
self.noise = self.noise/self.nbin

# Noise spectrum (diagonal in bin*bin space, independent of l and Bin)
self.noise = self.rms_shear**2/self.noise

################################################
# discrete theta values (to convert C_l to xi's)
################################################

thetamin = np.min(self.theta_bins)*0.8
thetamax = np.max(self.theta_bins)*1.2

self.nthetatot = np.ceil(math.log(thetamax/thetamin)/self.dlntheta) + 1
self.nthetatot = np.int32(self.nthetatot)
self.theta = np.zeros(self.nthetatot, 'float64')
self.a2r = math.pi/(180.*60.)

# define an array of theta's
for it in xrange(self.nthetatot):
    self.theta[it] = thetamin*math.exp(self.dlntheta*it)



ll=1.
il=0
while (ll*self.theta[-1]*self.a2r < self.dx_threshold):
    ll += self.dx_below_threshold/self.theta[-1]/self.a2r
    il += 1
for it  in xrange(self.nthetatot):
    while (ll*self.theta[self.nthetatot-1-it]*self.a2r < self.xmax) and (ll+self.dx_above_threshold/self.theta[self.nthetatot-1-it]/self.a2r < self.lmax):
        ll += self.dx_above_threshold/self.theta[self.nthetatot-1-it]/self.a2r
        il += 1
self.nl = il+1

self.lll = np.zeros(self.nl, 'float64')
self.il_max = np.zeros(self.nthetatot, 'int')
il=0
self.lll[il]=1.
while (self.lll[il]*self.theta[-1]*self.a2r < self.dx_threshold):
    il += 1
    self.lll[il] = self.lll[il-1] + self.dx_below_threshold/self.theta[-1]/self.a2r
for it  in xrange(self.nthetatot):
    while (self.lll[il]*self.theta[self.nthetatot-1-it]*self.a2r < self.xmax) and (self.lll[il] + self.dx_above_threshold/self.theta[self.nthetatot-1-it]/self.a2r < self.lmax):
        il += 1
        self.lll[il] = self.lll[il-1] + self.dx_above_threshold/self.theta[self.nthetatot-1-it]/self.a2r
    self.il_max[self.nthetatot-1-it] = il

# finally we compute the array l*dl that will be used in the trapezoidal integration
# (l is a factor in the integrand [l * C_l * Bessel], and dl is like a weight)
self.ldl = np.zeros(self.nl, 'float64')
self.ldl[0]=self.lll[0]*0.5*(self.lll[1]-self.lll[0])
for il in xrange(1,self.nl-1):
    self.ldl[il]=self.lll[il]*0.5*(self.lll[il+1]-self.lll[il-1])
    self.ldl[-1]=self.lll[-1]*0.5*(self.lll[-1]-self.lll[-2])
#####################################################################
# Allocation of various arrays filled and used in the function loglkl
#####################################################################

self.r = np.zeros(self.nzmax, 'float64')
self.dzdr = np.zeros(self.nzmax, 'float64')
self.g = np.zeros((self.nzmax, self.nbin), 'float64')
self.pk = np.zeros((self.nlmax, self.nzmax), 'float64')
self.k_sigma = np.zeros(self.nzmax, 'float64')
self.alpha = np.zeros((self.nlmax, self.nzmax), 'float64')
if 'epsilon' in self.use_nuisance:
    self.E_th_nu = np.zeros((self.nlmax, self.nzmax), 'float64')
self.nbin_pairs = self.nbin*(self.nbin+1)/2
self.Cl_integrand = np.zeros((self.nzmax, self.nbin_pairs), 'float64')
self.Cl = np.zeros((self.nlmax, self.nbin_pairs), 'float64')
if self.theoretical_error != 0:
    self.El_integrand = np.zeros((self.nzmax, self.nbin_pairs),'float64')
    self.El = np.zeros((self.nlmax, self.nbin_pairs), 'float64')
self.spline_Cl = np.empty(self.nbin_pairs, dtype=(list, 3))
self.xi1 = np.zeros((self.nthetatot, self.nbin_pairs), 'float64')
self.xi2 = np.zeros((self.nthetatot, self.nbin_pairs), 'float64')
self.Cll = np.zeros((self.nbin_pairs,self.nl), 'float64')
self.BBessel0 = np.zeros(self.nl, 'float64')
self.BBessel4 = np.zeros(self.nl, 'float64')
self.xi1_theta = np.empty(self.nbin_pairs, dtype=(list, 3))
self.xi2_theta = np.empty(self.nbin_pairs, dtype=(list, 3))
self.xi = np.zeros(np.size(self.xi_obs), 'float64')
self.use_halofit = True

# %%
from classy import Class
cosmo=Class()
cosmo.empty()



ListParams = {}


ListParams['MG/DE type']= 'qe'
ListParams['w_ds']= '-.6'
ListParams['cs2_ds']= '1.'
ListParams['B0']= '-1'
ListParams['has_logB0']= '1.'
ListParams['a_start_ds']= '0.01'
#ListParams['P_k_max_h/Mpc']= '3.'


ListParams['gauge']= 'syn'


#l_max_scalars =  1
#k_max_tau0_over_l_max = .1

#ListParams['l_max_scalars']= '9000'
#ListParams['k_max_tau0_over_l_max']= '.1'






ListParams['Omega_fld']= '0.'
#ListParams['Omega0_ds']= '0.'

ListParams['Omega_Lambda']= '0.'
ListParams['Omega_scf']= '0.'
ListParams['Omega_ncdm']= '0.'
ListParams['Omega_k']= '0.'







ListParams['omega_cdm']= '0.1197'
ListParams['A_s']= '2.198e-9'
ListParams['omega_b']= '0.02222' 
#ListParams['100*theta_s']= '1.04085' 
ListParams['h']= '0.6731' 
ListParams['n_s']= '0.9655' 
ListParams['tau_reio']= '0.078'

ListParams['sBBN file'] = '/Users/apple/Desktop/Pheno_EOS/Codes/class_eos/bbn/sBBN.dat' 
ListParams['k_pivot'] = 0.05

ListParams['N_ur'] = 2.0328 
ListParams['N_ncdm'] = 1 
ListParams['m_ncdm'] = 0.06 
ListParams['T_ncdm'] = 0.71611


ListParams['lensing']= 'no'

ListParams['P_k_max_h/Mpc']= '60' 
ListParams['z_max_pk']= '10.1' 
ListParams['k_per_decade_for_pk']= '5'

ListParams['perturb_sampling_stepsize']= '0.01'
ListParams['tol_perturb_integration']= '1.e-9'

ListParams['non linear'] = 'HALOFIT'
#ListParams['k_output_values'] = '1.,.1,0.01,0.001,0.0001,0.00001'

#ListParams['temperature contributions'] = 'lisw'#, eisw, lisw, dop, pol'
ListParams['output'] = 'mPk,mTk' 
ListParams['perturbations_verbose'] = '10'
ListParams['background_verbose'] = '0'

ListParams['lensing_verbose'] = '10'


ListParams['spectra_verbose'] = '10'







ListParams['omega_cdm']= '0.1133'
ListParams['A_s']= '1.86e-9'






ListParams['z_max_pk']= '3.52'

ListParams['gauge']= 'syn'
ListParams['output'] = 'mPk,mTk' 









self.use_halofit = True



#ListParams['l_max_scalars']= '800'
#ListParams['k_max_tau0_over_l_max']= '2.6'



#def loglkl(self, cosmo, data):
cosmo.set(ListParams)
cosmo.compute()
# One wants to obtain here the relation between z and r, this is done
# by asking the cosmological module with the function z_of_r

print 'sigma_8*(cosmo.Omega0_m()/0.27)**0.46'
print cosmo.sigma8()*(cosmo.Omega0_m()/0.27)**0.46

   
self.r, self.dzdr = cosmo.z_of_r(self.z_p)

# Compute now the selection function p(r) = p(z) dz/dr normalized
# to one. The np.newaxis helps to broadcast the one-dimensional array
# dzdr to the proper shape. Note that p_norm is also broadcasted as
# an array of the same shape as p_z
self.p_r = self.p*(self.dzdr[:, np.newaxis]/self.p_norm)

from scipy import special

# Compute function g_i(r), that depends on r and the bin
# g_i(r) = 2r(1+z(r)) int_r^+\infty drs p_r(rs) (rs-r)/rs
for Bin in xrange(self.nbin):
    for nr in xrange(1, self.nzmax-1):
        fun = self.p_r[nr:, Bin]*(self.r[nr:]-self.r[nr])/self.r[nr:]
        self.g[nr, Bin] = np.sum(0.5*(
                    fun[1:]+fun[:-1])*(self.r[nr+1:]-self.r[nr:-1]))
        self.g[nr, Bin] *= 2.*self.r[nr]*(1.+self.z_p[nr])

# Get power spectrum P(k=l/r,z(r)) from cosmological module
kmax_in_inv_Mpc = self.k_max_h_by_Mpc * cosmo.h()
for index_l in xrange(self.nlmax):
    for index_z in xrange(1, self.nzmax):
#                if (self.l[index_l]/self.r[index_z] > self.k_max):
#                    raise io_mp.LikelihoodError(
#                        "you should increase CFHTLens_correlation.k_max up"
#                        " to at least %g" % (self.l[index_l]/self.r[index_z]))
#                self.pk[index_l, index_z] = cosmo.pk(
#                    self.l[index_l]/self.r[index_z], self.z_p[index_z])
        k_in_inv_Mpc =  self.l[index_l]/self.r[index_z]
        if (k_in_inv_Mpc > kmax_in_inv_Mpc):
            self.pk[index_l, index_z] = 0.0
        else:
            self.pk[index_l, index_z] = cosmo.pk(k_in_inv_Mpc, self.z_p[index_z])
            #pk_nl = self.pk[index_l, index_z]
            
            #tk = cosmo.tk(k_in_inv_Mpc,self.z_p[index_z])[12]/cosmo.tk(k_in_inv_Mpc,self.z_p[index_z])[11]\
            #+cosmo.tk(k_in_inv_Mpc,self.z_p[index_z])[9]/cosmo.tk(k_in_inv_Mpc,self.z_p[index_z])[11]
            #tk = tk**2*2.*np.pi**2/k_in_inv_Mpc**3*As*(k_in_inv_Mpc/h/k_pivot)**(ns-1.)
            #self.pk[index_l, index_z] *= (1.-tk)**2


# Recover the non_linear scale computed by halofit. If no scale was
# affected, set the scale to one, and make sure that the nuisance
# parameter epsilon is set to zero
if (cosmo.nonlinear_method == 0):
    self.k_sigma[:] = 1.e6
else:
    self.k_sigma = cosmo.nonlinear_scale(self.z_p, self.nzmax)
#comment if USING halofit!!
#self.k_sigma[:] = 1.e6


# Define the alpha function, that will characterize the theoretical
# uncertainty. Chosen to be 0.001 at low k, raise between 0.1 and 0.2
# to self.theoretical_error
if self.theoretical_error != 0:
    for index_l in xrange(self.nlmax):
        k = self.l[index_l]/self.r[1:]
        self.alpha[index_l, 1:] = np.log(1.+k[:]/self.k_sigma[1:])/(
                    1.+np.log(1.+k[:]/self.k_sigma[1:]))*self.theoretical_error

# recover the e_th_nu part of the error function
e_th_nu = self.coefficient_f_nu*cosmo.Omega_nu/cosmo.Omega_m()

# Compute the Error E_th_nu function
if 'epsilon' in self.use_nuisance:
    for index_l in xrange(1, self.nlmax):
        self.E_th_nu[index_l, :] = np.log(
                    1.+self.l[index_l]/self.k_sigma[:]*self.r[:]) / (
                    1.+np.log(1.+self.l[index_l]/self.k_sigma[:]*self.r[:]))*e_th_nu
        
# Add the error function, with the nuisance parameter, to P_nl_th, if
# the nuisance parameter exists
        for index_l in xrange(self.nlmax):
            epsilon = data.mcmc_parameters['epsilon']['current']*(
                        data.mcmc_parameters['epsilon']['scale'])
            self.pk[index_l, :] *= (1.+epsilon*self.E_th_nu[index_l, :])

# Start loop over l for computation of C_l^shear
# Start loop over l for computation of E_l
for il in xrange(self.nlmax):
# find Cl_integrand = (g(r) / r)**2 * P(l/r,z(r))
    for Bin1 in xrange(self.nbin):
        for Bin2 in xrange(Bin1,self.nbin):
            self.Cl_integrand[1:, one_dim_index(Bin1,Bin2)] = self.g[1:, Bin1]*self.g[1:, Bin2]/(self.r[1:]**2)*self.pk[il, 1:]
            if self.theoretical_error != 0:
                self.El_integrand[1:, one_dim_index(Bin1, Bin2)] = self.g[1:, Bin1]*(self.g[1:, Bin2])/(self.r[1:]**2)*self.pk[il, 1:]*self.alpha[il, 1:]
            
        # Integrate over r to get C_l^shear_ij = P_ij(l)
        # C_l^shear_ij = 9/16 Omega0_m^2 H_0^4 \sum_0^rmax dr (g_i(r)
        # g_j(r) /r**2) P(k=l/r,z(r)) dr
        # It is then multiplied by 9/16*Omega_m**2
        # and then by (h/2997.9)**4 to be dimensionless
        # (since P(k)*dr is in units of Mpc**4)
        for Bin in xrange(self.nbin_pairs):
            self.Cl[il, Bin] = np.sum(0.5*(self.Cl_integrand[1:, Bin] + self.Cl_integrand[:-1, Bin])*(self.r[1:]-self.r[:-1]))
            self.Cl[il, Bin] *= 9./16.*(cosmo.Omega_m())**2
            self.Cl[il, Bin] *= (cosmo.h()/2997.9)**4

            if self.theoretical_error != 0:
                self.El[il, Bin] = np.sum(0.5*(self.El_integrand[1:, Bin] + self.El_integrand[:-1, Bin])*(self.r[1:]-self.r[:-1]))
                self.El[il, Bin] *= 9./16.*(cosmo.Omega_m())**2
                self.El[il, Bin] *= (cosmo.h()/2997.9)**4
                
            for Bin1 in xrange(self.nbin):
                self.Cl[il, one_dim_index(Bin1, Bin1)] += self.noise


# Spline Cl[il,Bin1,Bin2] along l
for Bin in xrange(self.nbin_pairs):
    self.spline_Cl[Bin] = list(itp.splrep(self.l, self.Cl[:, Bin]))

# Interpolate Cl at values lll and store results in Cll
for Bin in xrange(self.nbin_pairs):
    self.Cll[Bin,:] = itp.splev(self.lll[:], self.spline_Cl[Bin])

# Start loop over theta values
for it in xrange(self.nthetatot):
    ilmax = self.il_max[it]
    self.BBessel0[:ilmax] = special.j0(self.lll[:ilmax]*self.theta[it]*self.a2r)
    self.BBessel4[:ilmax] = special.jv(4,self.lll[:ilmax]*self.theta[it]*self.a2r)
    # Here is the actual trapezoidal integral giving the xi's:
    # - in more explicit style:
    # for Bin in xrange(self.nbin_pairs):
    #     for il in xrange(ilmax):
    #         self.xi1[it, Bin] = np.sum(self.ldl[il]*self.Cll[Bin,il]*self.BBessel0[il])
    #         self.xi2[it, Bin] = np.sum(self.ldl[il]*self.Cll[Bin,il]*self.BBessel4[il])
    # - in more compact and vectorizable style:
    self.xi1[it, :] = np.sum(self.ldl[:ilmax]*self.Cll[:,:ilmax]*self.BBessel0[:ilmax],axis=1)
    self.xi2[it, :] = np.sum(self.ldl[:ilmax]*self.Cll[:,:ilmax]*self.BBessel4[:ilmax],axis=1)

# normalisation of xi's
self.xi1 = self.xi1/(2.*math.pi)
self.xi2 = self.xi2/(2.*math.pi)

# Spline the xi's
for Bin in xrange(self.nbin_pairs):
    self.xi1_theta[Bin] = list(itp.splrep(self.theta, self.xi1[:,Bin]))
    self.xi2_theta[Bin] = list(itp.splrep(self.theta, self.xi2[:,Bin]))

# Get xi's in same column vector format as the data
#iz = 0
#for Bin in xrange(self.nbin_pairs):
#    iz = iz + 1  # this counts the bin combinations
#    for i in xrange(self.ntheta):
#        j = (iz-1)*2*self.ntheta
#        self.xi[j+i] = itp.splev(
#            self.theta_bins[i], self.xi1_theta[Bin])
#        self.xi[self.ntheta + j+i] = itp.splev(
#            self.theta_bins[i], self.xi2_theta[Bin])
# or in more compact/vectorizable form:
iz = 0
for Bin in xrange(self.nbin_pairs):
    iz = iz + 1  # this counts the bin combinations
    j = (iz-1)*2*self.ntheta
    self.xi[j:j+self.ntheta] = itp.splev(self.theta_bins[:self.ntheta], self.xi1_theta[Bin])
    self.xi[j+self.ntheta:j+2*self.ntheta] = itp.splev(self.theta_bins[:self.ntheta], self.xi2_theta[Bin])

# final chi2
vec = self.xi[self.mask_indices] - self.xi_obs[self.mask_indices]
chi2 = np.dot(vec, np.dot(self.wl_invcov, vec))

print -chi2/2.
# Out:
# sigma_8*(cosmo.Omega0_m()/0.27)**0.46
# 0.650056889406
# -13.2751121671

# %%
labels = [r'$0.20\leq z_{_{\mathrm{BPZ}}}<0.39$',
          r'$0.39\leq z_{_{\mathrm{BPZ}}}<0.58$',
          r'$0.58\leq z_{_{\mathrm{BPZ}}}<0.72$',
          r'$0.72\leq z_{_{\mathrm{BPZ}}}<0.86$',
          r'$0.86\leq z_{_{\mathrm{BPZ}}}<1.02$',
          r'$1.02\leq z_{_{\mathrm{BPZ}}}<1.30$',
         ]
colors = [(0.,0.,0.),(0.15,0.15,0.15),(0.3,0.3,0.3),
          (0.45,0.45,0.45),(0.60,0.6,0.6),(0.75,0.75,0.75)]




N_plots = self.nbin


label_size = 20
handle_length = 1.
fig, (ax1) = plt.subplots(1,1,figsize=(9,5))

ax = ax1
for i in range (N_plots):
    ax.plot(self.z_p,self.p[:,i],label=labels[i],color=colors[i])

    
ax.set_xlim(0.01,1.5)
ax.set_ylim(0.01,0.85)
ax.set_xscale('linear')   
ax.set_yscale('linear')
ax.set_xlabel('$z$',size=25)
ax.set_ylabel('$p(z)$',size=25)
ax.legend(loc='upper center',prop={'size':16},ncol=3,handlelength=handle_length,frameon=False)
ax.tick_params(axis = 'x',length=5,which='both',direction='in', pad=10)
ax.tick_params(axis = 'y',length=5,which='both',direction='in', pad=5)


#plt.text(0.9,0.1,r'$B_{_0} = 1$',horizontalalignment='center',
#     verticalalignment='center', transform = ax.transAxes,fontsize=16)




plt.setp(ax.get_yticklabels(), rotation='vertical', fontsize=label_size)
plt.setp(ax.get_xticklabels(),fontsize=label_size)
ax.xaxis.labelpad = -5
ax.yaxis.labelpad = 5



fig.tight_layout()

plt.savefig("p_of_zCFHT.pdf")

# %%
label_size = 22
title_size = 25
legend_size = 20
fig, (ax1) = plt.subplots(1,1,figsize=(7,5))

ax = ax1
p = 190

sigma2 = covmat.diagonal()
yerr = np.sqrt(sigma2[p:p+5])
y = self.xi_obs[p:p+5]
x = self.theta_bins[0:5]


verr =  yerr
v = y
verr2 = np.array(verr)
verr2[verr>=v] = v[verr>=v]*.999999

ax.errorbar(x, y, yerr = [verr2,verr],capthick=2,capsize=5,
            linewidth = 2,
            elinewidth=2,
            markersize=10,
          fmt='o',color = 'k',ls='none',
          label=r'$\mathrm{CFHTLenS}$')

ax.set_ylim(2.e-6,6.e-4)
ax.set_xscale('log')

ax.set_yscale('log')


t = 0.
ax.plot(x,XI_lcdm,color=(t,t,t), ls='-',
         label=r'$w_{_\mathrm{de}}=-1.4$')

# %%
#i = 1
#j = 6
label_size = 22
title_size = 25
legend_size = 20
fig, (ax1) = plt.subplots(1,1,figsize=(7,5))

ax = ax1
p = 190

sigma2 = covmat.diagonal()
yerr = np.sqrt(sigma2[p:p+5])
y = self.xi_obs[p:p+5]
x = self.theta_bins[0:5]


verr =  yerr
v = y
verr2 = np.array(verr)
verr2[verr>=v] = v[verr>=v]*.999999

#ax.errorbar(x, y, yerr = [verr2,verr],capthick=2,capsize=5,
#            linewidth = 2,
##             elinewidth=2,
 ##            markersize=10,
   #          fmt='o',color = 'k',ls='none',
    #       label=r'$\mathrm{CFHTLenS}$')


ax.set_ylim(2.e-6,6.e-4)
ax.set_xscale('log')

ax.set_yscale('log')


t = 0.
ax.plot(x,XI_w_m1d4,color=(t,t,t), ls='-',
         label=r'$w_{_\mathrm{de}}=-1.4$')


t+=0.15
ax.plot(x,XI_w_m1d2,color=(t,t,t), ls='-',
         label=r'$w_{_\mathrm{de}}=-1.2$')



t+=0.15
ax.plot(x,XI_lcdm,color=(t,t,t), ls='-',
         label=r'$w_{_\mathrm{de}}=-1$')

t+=0.15
ax.plot(x,XI_w_m0d8,color=(t,t,t), ls='-',
         label=r'$w_{_\mathrm{de}}=-0.8$')


t+=0.15
ax.plot(x,XI_w_m0d6,color=(t,t,t), ls='-',
         label=r'$w_{_\mathrm{de}}=-0.6$')





#ax.plot(x,XI_lcdm,color='black', ls='--',
#         label=r'$\mathrm{\Lambda CDM}$')




#ax.plot(x,XI_B0_1,color='black', ls='--',
#         label=r'$B_{_{\mathrm{0}}}=1$')




#ax.plot(x,Linear_56,color='black', ls='--',
#         label=r'$\sigma_{_{8}}(\Omega_{_{\mathrm{m}}}/0.27)^{0.46}=0.774$')




ax.set_xlabel(r'$\theta \,\,\mathrm{[arcmin]}$',size=title_size)
ax.set_ylabel(r'$\xi_{+}^{5,6}(\theta)$',size=title_size)
ax.legend(loc=1,prop={'size':legend_size},ncol=2,numpoints=1,markerfirst=True,
          handlelength=handle_length,frameon=False)

frame = legend.get_frame()
cl = 0.2
frame.set_edgecolor((cl,cl,cl))





ax.tick_params(axis = 'x',length=5,which='both',direction='in', pad=10)
ax.tick_params(axis = 'y',length=5,which='both',direction='in', pad=5)


plt.text(0.15,0.1,r'$c_{_{s,\mathrm{de}}}=1$',horizontalalignment='center',
     verticalalignment='center', transform = ax.transAxes,
         fontsize=legend_size)
ax.xaxis.set_label_coords(.5,-0.11) 





plt.setp(ax.get_yticklabels(), rotation='vertical', fontsize=label_size)
plt.setp(ax.get_xticklabels(), fontsize=label_size)
ax.xaxis.labelpad = -5
ax.yaxis.labelpad = 5



fig.tight_layout()

plt.savefig("w-CFHT.pdf")

# %%
#i = 1
#j = 6
label_size = 22
title_size = 25
legend_size = 20
fig, (ax1) = plt.subplots(1,1,figsize=(7,5))

ax = ax1
p = 190

sigma2 = covmat.diagonal()
yerr = np.sqrt(sigma2[p:p+5])
y = self.xi_obs[p:p+5]
x = self.theta_bins[0:5]


verr =  yerr
v = y
verr2 = np.array(verr)
verr2[verr>=v] = v[verr>=v]*.999999

#ax.errorbar(x, y, yerr = [verr2,verr],capthick=2,capsize=5,
#            linewidth = 2,
##             elinewidth=2,
 ##            markersize=10,
   #          fmt='o',color = 'k',ls='none',
    #       label=r'$\mathrm{CFHTLenS}$')


ax.set_ylim(2.e-6,6.e-4)
ax.set_xscale('log')

ax.set_yscale('log')


t = 0.
ax.plot(x,XI_B0_1em4,color=(t,t,t), ls='-',
         label=r'$B_{_{\mathrm{0}}}=10^{-4}$')


t+=0.15
ax.plot(x,XI_B0_1em1,color=(t,t,t), ls='-',
         label=r'$B_{_{\mathrm{0}}}=10^{-1}$')



t+=0.15
ax.plot(x,XI_B0_1,color=(t,t,t), ls='-',
         label=r'$B_{_{\mathrm{0}}}=10$')

t+=0.15
ax.plot(x,XI_B0_5,color=(t,t,t), ls='-',
         label=r'$B_{_{\mathrm{0}}}=5$')




ax.plot(x,XI_lcdm,color='black', ls='--',
         label=r'$\mathrm{\Lambda CDM}$')




#ax.plot(x,XI_B0_1,color='black', ls='--',
#         label=r'$B_{_{\mathrm{0}}}=1$')




#ax.plot(x,Linear_56,color='black', ls='--',
#         label=r'$\sigma_{_{8}}(\Omega_{_{\mathrm{m}}}/0.27)^{0.46}=0.774$')




ax.set_xlabel(r'$\theta \,\,\mathrm{[arcmin]}$',size=title_size)
ax.set_ylabel(r'$\xi_{+}^{5,6}(\theta)$',size=title_size)
ax.legend(loc=3,prop={'size':legend_size},ncol=3,numpoints=1,markerfirst=True,
          handlelength=handle_length,frameon=False)

frame = legend.get_frame()
cl = 0.2
frame.set_edgecolor((cl,cl,cl))





ax.tick_params(axis = 'x',length=5,which='both',direction='in', pad=10)
ax.tick_params(axis = 'y',length=5,which='both',direction='in', pad=5)


plt.text(0.85,0.9,r'$w_{_\mathrm{de}}=-1$',horizontalalignment='center',
     verticalalignment='center', transform = ax.transAxes,
         fontsize=legend_size)
ax.xaxis.set_label_coords(.5,-0.11) 





plt.setp(ax.get_yticklabels(), rotation='vertical', fontsize=label_size)
plt.setp(ax.get_xticklabels(), fontsize=label_size)
ax.xaxis.labelpad = -5
ax.yaxis.labelpad = 5



fig.tight_layout()

plt.savefig("B0-CFHT.pdf")

# %%
#i = 1
#j = 6
label_size = 22
title_size = 25
fig, (ax1) = plt.subplots(1,1,figsize=(7,5))

ax = ax1
p = 190

sigma2 = covmat.diagonal()
yerr = np.sqrt(sigma2[p:p+5])
y = self.xi_obs[p:p+5]
x = self.theta_bins[0:5]


verr =  yerr
v = y
verr2 = np.array(verr)
verr2[verr>=v] = v[verr>=v]*.999999

ax.errorbar(x, y, yerr = [verr2,verr],capthick=2,capsize=5,
            linewidth = 2,
             elinewidth=2,
             markersize=10,
             fmt='o',color = 'k',ls='none',
           label=r'$\mathrm{CFHTLenS}$')


ax.set_ylim(2.e-6,6.e-4)
ax.set_xscale('log')

ax.set_yscale('log')



ax.plot(x,XI_lcdm,color='black', ls='-',
         label=r'$\mathrm{halofit}$')



ax.plot(x,XI_lcdm_lin,color='black', ls='--',
         label=r'$\mathrm{linear}$')




#ax.plot(x,XI_B0_1,color='black', ls='--',
#         label=r'$B_{_{\mathrm{0}}}=1$')




#ax.plot(x,Linear_56,color='black', ls='--',
#         label=r'$\sigma_{_{8}}(\Omega_{_{\mathrm{m}}}/0.27)^{0.46}=0.774$')




ax.set_xlabel(r'$\theta \,\,\mathrm{[arcmin]}$',size=title_size)
ax.set_ylabel(r'$\xi_{+}^{5,6}(\theta)$',size=title_size)
legend = ax.legend(loc=1,prop={'size':22},ncol=1,numpoints=1,markerfirst=True,
          handlelength=handle_length,frameon=True)


frame = legend.get_frame()
cl = 0.2
frame.set_edgecolor((cl,cl,cl))




ax.tick_params(axis = 'x',length=5,which='both',direction='in', pad=10)
ax.tick_params(axis = 'y',length=5,which='both',direction='in', pad=5)


plt.text(0.15,0.1,r'$\Lambda\mathrm{CDM}$',horizontalalignment='center',
     verticalalignment='center', transform = ax.transAxes,
         fontsize=legend_size)
ax.xaxis.set_label_coords(.5,-0.11) 




plt.setp(ax.get_yticklabels(), rotation='vertical', fontsize=label_size)
plt.setp(ax.get_xticklabels(), fontsize=label_size)
ax.xaxis.labelpad = -5
ax.yaxis.labelpad = 5



fig.tight_layout()

plt.savefig("bestfit-CFHT.pdf")

# %%
XI_lcdm = np.zeros(len(self.xi[p:p+5]))
for i in range (len(self.xi[p:p+5])):
    XI_lcdm[i]=self.xi[p:p+5][i]

# %%
XI_w_m0d6 = np.zeros(len(self.xi[p:p+5]))
for i in range (len(self.xi[p:p+5])):
    XI_w_m0d6[i]=self.xi[p:p+5][i]

# %%
XI_lcdm
# Out:
# array([  6.41383417e-05,   5.83668988e-05,   3.99070947e-05,
#          2.07729616e-05,   1.03638665e-05])

# %%
T0=np.loadtxt("output/LCDM_fR_w=-1_B0=1_matterpower0.dat")
T1=np.loadtxt("output/test_fR_w=-1._logB0=0._synpk.dat")
T2=np.loadtxt("output/test_fR_w=-1._logB0=0._syntk.dat")
T3=np.loadtxt("output/LCDM_fR_w=-1_B0=1_transfer_out0.dat")
T4=np.loadtxt("output/test_fR_w=-1._logB0=0._synperturbations_k3_s_ZIC.dat")

T4bis=np.loadtxt("output/test_fR_w=-1._logB0=0._synperturbations_k3_s_AIC.dat")

# %%
k0=T0[:,0]
pk0=T0[:,1]
k1=T1[:,0]
pk1=T1[:,1]
f2 = InterpolatedUnivariateSpline(k0, pk0)
k2=T2[:,0]
phi=T2[:,6]
psi=T2[:,7]
k3=T3[:,0]
weyl=T3[:,9]
f3 = InterpolatedUnivariateSpline(k3, weyl)

z=1./T4[:,1]-1.
O_ds_D_ds = T4[:,22]
zbis=1./T4bis[:,1]-1.
O_ds_D_dsbis = T4bis[:,22]

# %%
plt.plot(zbis,np.abs(O_ds_D_dsbis))


plt.plot(z,np.abs(O_ds_D_ds))


plt.loglog()
plt.ylim(0.1,100000)
plt.xlim(0.01,1000)
# Out:
# (0.01, 1000)

# %%
plt.plot(k1,pk1)
#plt.plot(k0,pk0)

plt.plot(k1,f2(k1))

plt.loglog()
# Out:
# []

# %%
plt.plot(k1,f2(k1)/pk1)
plt.xscale('log')

# %%
plt.plot(k1,f2(k1)/pk1)
plt.xscale('log')

# %%
plt.plot(k3,weyl)
plt.plot(k2,-(phi+psi)/2.)


plt.ylabel(r'$W$',size=25)
plt.xscale('log')

# %%
plt.plot(k2,(-(phi+psi)/2.-f3(k2))/f3(k2))
plt.xscale('log')
plt.ylabel(r'$\delta W /W$',size=25)

# %%
T0=np.loadtxt("output/test-pk.dat")
T1=np.loadtxt("output/test-_fR_w=-1._logB0=-1._synpk.dat")
T2=np.loadtxt("output/test-_qe_w=-1._cs2=1._synpk.dat")

# %%
T0=np.loadtxt("output/test-no-de-_fR_w=-1._logB0=-1._syncl.dat")
T2=np.loadtxt("output/test-ini-_fR_w=-1._logB0=-1._syncl.dat")
T3=np.loadtxt("output/test-final-_fR_w=-1._logB0=0._syncl.dat")

T4=np.loadtxt("output/test-final-_fR_w=-1._logB0=-5._syncl.dat")



x2 = T0[:,0]
y2 = T0[:,1]
#plt.plot(x,y,label='old')
plt.plot(x2,y2,label='new')

x2 = T2[:,0]
y2 = T2[:,1]
#plt.plot(x,y,label='old')
plt.plot(x2,y2,label='ini')
x2 = T3[:,0]
y2 = T3[:,1]
#plt.plot(x,y,label='old')
plt.plot(x2,y2,label='ini2')
x2 = T4[:,0]
y2 = T4[:,1]
#plt.plot(x,y,label='old')
plt.plot(x2,y2,label='ini3')
#plt.plot(x,y3)
plt.legend()
plt.loglog()

plt.figure(2)
T0=np.loadtxt("output/test-no-de-_fR_w=-1._logB0=-1._synpk.dat")
T2=np.loadtxt("output/test-ini-_fR_w=-1._logB0=-1._synpk.dat")
T3=np.loadtxt("output/test-final-_fR_w=-1._logB0=-5._synpk.dat")

T4=np.loadtxt("output/test-final-_fR_w=-1._logB0=0._synpk.dat")



x2 = T0[:,0]
y2 = T0[:,1]
#plt.plot(x,y,label='old')
plt.plot(x2,y2,label='new')

x2 = T2[:,0]
y2 = T2[:,1]
#plt.plot(x,y,label='old')
plt.plot(x2,y2,label='ini')
x2 = T3[:,0]
y2 = T3[:,1]
#plt.plot(x,y,label='old')
plt.plot(x2,y2,label='ini2')
x2 = T4[:,0]
y2 = T4[:,1]
#plt.plot(x,y,label='old')
plt.plot(x2,y2,label='ini3')
#plt.plot(x,y3)
plt.legend()
plt.loglog()
# Out:
# []

# %%
T0=np.loadtxt("output/test-pk.dat")
T1=np.loadtxt("output/test-_fR_w=-1._logB0=-1._synpk.dat")
T2=np.loadtxt("output/test-_qe_w=-1._cs2=1._synpk.dat")

x2 = T0[:,0]
y2 = T0[:,1]
#plt.plot(x,y,label='old')
plt.plot(x2,y2,label='new')
x2 = T1[:,0]
y2 = T1[:,1]
#plt.plot(x,y,label='old')
plt.plot(x2,y2,label='new')
x2 = T2[:,0]
y2 = T2[:,1]
#plt.plot(x,y,label='old')
plt.plot(x2,y2,label='new')
#plt.plot(x,y3)
plt.legend()
plt.loglog()
# Out:
# []

# %%
T1=np.loadtxt("output/test-speed_fR_w=-1._logB0=0._syncl.dat")

# %%
x = T1[:,0]
y = T1[:,1]
plt.plot(x,y,label='old')
#plt.plot(x2,y2,label='new')
#plt.plot(x,y3)
plt.legend()
plt.loglog()
# Out:
# []
